# %% [markdown]
# # Getting Event and Market Data
#
# So to get started with this, let's check out the [Polymarket API](https://docs.polymarket.com/).
#
# Gamma Markets - https://gamma-api.polymarket.com
#
# https://polymarket.com/event/what-will-kamala-say-during-acceptance-speech?tid=1724353609658
#
# An event is a set of markets. For example:
#
# **Event** - What will Kamala Harris say during her acceptance speech?
#   - **Market** - We're not going back (Yes/No)
#   - **Market** - Ceasefire (Yes/No)
#   - **Market** - Joy (Yes/No)
#   - **Market** - Inflation (Yes/No)
#   - **Market** - Donald Trump (Yes/No)
#   - **Market** - Monkeypox (Yes/No)
#
# Sometimes there is only 1 market for an event.
#
# **Event** - Will Beyonce attend the DNC?
#
# **Event** - Will Taylor Swift attend the DNC?
#
# So in this phase of our research, we would be using the Gamma API, which is a REST API, a web endpoint. We're exploring the various bets or contracts that are available. And we can think about what we know about them, are there data sources we can explore or anything we can think of to try to beat the odds. Once we have explored these, we can use another API to see what other people are doing in real time. How are these Yes / No values moving second by second. During the speech, when does a value start spiking or plummeting.

# %%
import requests

r = requests.get("https://gamma-api.polymarket.com/events?closed=false")
response = r.json()

response
# Out:
# [{'id': '903193',
#   'ticker': 'presidential-election-winner-2024',
#   'slug': 'presidential-election-winner-2024',
#   'title': 'Presidential Election Winner 2024',
#   'description': 'This is a market on predicting the winner of the 2024 presidential election.',
#   'resolutionSource': '',
#   'startDate': '2024-01-04T22:58:00Z',
#   'creationDate': '2024-01-04T23:04:57.844Z',
#   'endDate': '2024-11-04T12:00:00Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/presidential-election-winner-2024-afdda358-219d-448a-abb5-ba4d14118d71.png',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/presidential-election-winner-2024-afdda358-219d-448a-abb5-ba4d14118d71.png',
#   'active': True,
#   'closed': False,
#   'archived': False,
#   'new': False,
#   'featured': True,
#   'restricted': True,
#   'liquidity': 141776521.53594,
#   'volume': 698334927.618085,
#   'openInterest': 0,
#   'sortBy': 'price',
#   'published_at': '2024-01-04 17:33:51.448+00',
#   'updatedBy': '15',
#   'createdAt': '2024-01-04T17:33:51.47Z',
#   'updatedAt': '2024-08-23T01:09:09.399116Z',
#   'commentsEnabled': False,
#   'competitive': 0.9997750506136119,
#   'volume24hr': 11128381.67,
#   'featuredImage': '',
#   'enableOrderBook': True,
#   'liquidityClob': 141776521.53594,
#   '_sync': False,
#   'negRisk': True,
#   'negRiskMarketID': '0xe3b1bc389210504ebcb9cffe4b0ed06ccac50561e0f24abb6379984cec030f00',
#   'negRiskFeeBips': 0,
#   'commentCount': 35714,
#   'markets': [{'id': '253591',
#     'question': 'Will Donald Trump win the 2024 US Presidential Election?',
#     'conditionId': '0xdd22472e552920b8438158ea7238bfadfa4f736aa4cee91a6b86c39ead110917',
#     'slug': 'will-donald-trump-win-the-2024-us-presidential-election',
#     'resolutionSource': '',
#     'endDate': '2024-11-05T00:00:00Z',
#     'liquidity': '804620.48114',
#     'startDate': '2024-01-04T22:58:00Z',
#     'fee': '20000000000000000',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-donald-trump-win-the-2024-us-presidential-election-c83f01bb-5089-4222-9347-3f12673b6a48.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-donald-trump-win-the-2024-us-presidential-election-c83f01bb-5089-4222-9347-3f12673b6a48.png',
#     'description': 'This market will resolve to “Yes” if Donald J. Trump wins the 2024 US Presidential Election. Otherwise, this market will resolve to “No.”\n\nThe resolution source for this market is the Associated Press, Fox News, and NBC. This market will resolve once all three sources call the race for the same candidate. If all three sources haven’t called the race for the same candidate by the inauguration date (January 20, 2025) this market will resolve based on who is inaugurated.',
#     'outcomes': '["Yes", "No"]',
#     'outcomePrices': '["0.515", "0.485"]',
#     'volume': '86447954.366593',
#     'active': True,
#     'marketType': 'normal',
#     'closed': False,
#     'marketMakerAddress': '',
#     'updatedBy': 15,
#     'createdAt': '2024-01-04T17:33:51.332Z',
#     'updatedAt': '2024-08-23T01:10:14.833298Z',
#     'wideFormat': False,
#     'new': False,
#     'featured': False,
#     'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#     'archived': False,
#     'resolvedBy': '0x2F5e3684cb1F318ec51b00Edba38d79Ac2c0aA9d',
#     'restricted': True,
#     'groupItemTitle': 'Donald Trump',
#     'groupItemThreshold': '1',
#     'questionID': '0xe3b1bc389210504ebcb9cffe4b0ed06ccac50561e0f24abb6379984cec030f00',
#     'enableOrderBook': True,
#     'orderPriceMinTickSize': 0.001,
#     'orderMinSize': 5,
#     'volumeNum': 86447954.37,
#     'liquidityNum': 804620.48,
#     'endDateIso': '2024-11-05',
#     'startDateIso': '2024-01-04',
#     'hasReviewedDates': True,
#     'commentsEnabled': False,
#     'volume24hr': 1447729.13,
#     'secondsDelay': 0,
#     'clobTokenIds': '["21742633143463906290569050155826241533067272736897614950488156847949938836455", "48331043336612883890938759509493159234755048973500640148014422747788308965732"]',
#     'umaBond': '99750.0',
#     'umaReward': '500.0',
#     'fpmmLive': True,
#     'volume24hrClob': 1447729.129529,
#     'volumeClob': 86447954.366593,
#     'liquidityClob': 804620.48114,
#     'makerBaseFee': 0,
#     'takerBaseFee': 0,
#     'customLiveness': 0,
#     'acceptingOrders': True,
#     'negRisk': True,
#     'negRiskMarketID': '0xe3b1bc389210504ebcb9cffe4b0ed06ccac50561e0f24abb6379984cec030f00',
#     'negRiskRequestID': '0xc2d6714f691eacd6ec494c7d6e5eaaf7dfba8907dcaf55b2dd93e7b479da1605',
#     'commentCount': 16123,
#     'notificationsEnabled': False,
#     '_sync': False,
#     'creator': '',
#     'ready': False,
#     'funded': False,
#     'tags': [{'id': '126',
#       'label': 'Trump',
#       'slug': 'trump',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:23:16.384+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:23:16.39Z',
#       'updatedAt': '2024-05-31T01:02:06.643434Z',
#       '_sync': False},
#      {'id': '2',
#       'label': 'Politics',
#       'slug': 'politics',
#       'forceShow': False,
#       'publishedAt': '2023-10-25 18:55:50.674+00',
#       'updatedBy': 13,
#       'createdAt': '2023-10-25T18:55:50.681Z',
#       'updatedAt': '2024-07-05T21:07:05.081707Z',
#       '_sync': False,
#       'forceHide': True},
#      {'id': '1101',
#       'label': 'us presidential election',
#       'slug': 'us-presidential-election',
#       'publishedAt': '2024-02-06 19:42:10.126+00',
#       'createdAt': '2024-02-06T19:42:10.132Z',
#       'updatedAt': '2024-02-06T19:42:10.132Z',
#       '_sync': True},
#      {'id': '214',
#       'label': 'hillary clinton',
#       'slug': 'hillary-clinton',
#       'publishedAt': '2023-11-02 21:36:44.111+00',
#       'createdAt': '2023-11-02T21:36:44.126Z',
#       'updatedAt': '2023-11-02T21:36:44.126Z',
#       '_sync': True},
#      {'id': '15',
#       'label': 'Joe Biden',
#       'slug': 'joe-biden',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:03:39.389+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:03:39.396Z',
#       'updatedAt': '2024-04-24T19:34:18.314621Z',
#       '_sync': False},
#      {'id': '24',
#       'label': 'US Election',
#       'slug': 'us-election',
#       'forceShow': True,
#       'publishedAt': '2023-11-02 21:04:03.712+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:04:03.723Z',
#       'updatedAt': '2024-05-01T17:30:24.691205Z',
#       '_sync': False},
#      {'id': '945',
#       'label': 'michelle obama',
#       'slug': 'michelle-obama',
#       'publishedAt': '2024-02-01 19:15:00.647+00',
#       'createdAt': '2024-02-01T19:15:00.664Z',
#       'updatedAt': '2024-02-01T19:15:00.664Z',
#       '_sync': True},
#      {'id': '382',
#       'label': 'chris christie',
#       'slug': 'chris-christie',
#       'publishedAt': '2023-11-02 22:09:15.517+00',
#       'createdAt': '2023-11-02T22:09:15.535Z',
#       'updatedAt': '2023-11-02T22:09:15.535Z',
#       '_sync': True},
#      {'id': '160',
#       'label': 'ron desantis',
#       'slug': 'ron-desantis',
#       'publishedAt': '2023-11-02 21:27:54.001+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:27:54.02Z',
#       'updatedAt': '2024-03-07T06:56:40.555Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '26',
#       'label': 'republican party',
#       'slug': 'republican-party',
#       'publishedAt': '2023-11-02 21:04:05.072+00',
#       'createdAt': '2023-11-02T21:04:05.078Z',
#       'updatedAt': '2023-11-02T21:04:05.078Z',
#       '_sync': True},
#      {'id': '1104',
#       'label': 'bernie sanders',
#       'slug': 'bernie-sanders',
#       'publishedAt': '2024-02-06 19:43:33.313+00',
#       'createdAt': '2024-02-06T19:43:33.328Z',
#       'updatedAt': '2024-02-06T19:43:33.328Z',
#       '_sync': True},
#      {'id': '187',
#       'label': 'kanye west',
#       'slug': 'kanye-west',
#       'publishedAt': '2023-11-02 21:32:10.391+00',
#       'createdAt': '2023-11-02T21:32:10.407Z',
#       'updatedAt': '2023-11-02T21:32:10.407Z',
#       '_sync': True},
#      {'id': '1102',
#       'label': '2024 us presidential election',
#       'slug': '2024-us-presidential-election',
#       'publishedAt': '2024-02-06 19:42:21.109+00',
#       'createdAt': '2024-02-06T19:42:21.114Z',
#       'updatedAt': '2024-02-06T19:42:21.114Z',
#       '_sync': True},
#      {'id': '142',
#       'label': 'nikki haley',
#       'slug': 'nikki-haley',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:24:28.845+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:24:28.852Z',
#       'updatedAt': '2024-02-08T19:46:31.92Z',
#       '_sync': True},
#      {'id': '152',
#       'label': 'democratic party',
#       'slug': 'democratic-party',
#       'publishedAt': '2023-11-02 21:26:09.156+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:26:09.164Z',
#       'updatedAt': '2024-02-11T18:06:11.376Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '177',
#       'label': 'gavin newsom',
#       'slug': 'gavin-newsom',
#       'publishedAt': '2023-11-02 21:30:46.001+00',
#       'createdAt': '2023-11-02T21:30:46.018Z',
#       'updatedAt': '2023-11-02T21:30:46.018Z',
#       '_sync': True},
#      {'id': '589',
#       'label': 'us presidential election 2024',
#       'slug': 'us-presidential-election-2024',
#       'publishedAt': '2023-11-29 16:29:56.03+00',
#       'createdAt': '2023-11-29T16:29:56.045Z',
#       'updatedAt': '2023-11-29T16:29:56.045Z',
#       '_sync': True},
#      {'id': '176',
#       'label': 'us elections',
#       'slug': 'us-elections',
#       'publishedAt': '2023-11-02 21:30:44.182+00',
#       'createdAt': '2023-11-02T21:30:44.188Z',
#       'updatedAt': '2023-11-02T21:30:44.188Z',
#       '_sync': True},
#      {'id': '144',
#       'label': 'Elections',
#       'slug': 'elections',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:24:31.008+00',
#       'updatedBy': 13,
#       'createdAt': '2023-11-02T21:24:31.198Z',
#       'updatedAt': '2024-05-03T15:51:20.233636Z',
#       '_sync': False,
#       'forceHide': True},
#      {'id': '1103',
#       'label': 'aoc',
#       'slug': 'aoc',
#       'publishedAt': '2024-02-06 19:43:17.999+00',
#       'createdAt': '2024-02-06T19:43:18.005Z',
#       'updatedAt': '2024-02-06T19:43:18.005Z',
#       '_sync': True},
#      {'id': '185',
#       'label': '2024 election',
#       'slug': '2024-election',
#       'publishedAt': '2023-11-02 21:31:45.201+00',
#       'createdAt': '2023-11-02T21:31:45.209Z',
#       'updatedAt': '2023-11-02T21:31:45.209Z',
#       '_sync': True},
#      {'id': '360',
#       'label': 'robert f. kennedy jr.',
#       'slug': 'robert-fpt-kennedy-jrpt',
#       'publishedAt': '2023-11-02 22:04:07.269+00',
#       'createdAt': '2023-11-02T22:04:07.284Z',
#       'updatedAt': '2023-11-02T22:04:07.284Z',
#       '_sync': True},
#      {'id': '57',
#       'label': '2024 presidential election',
#       'slug': '2024-presidential-election',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:15:04.115+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:15:04.125Z',
#       'updatedAt': '2024-02-17T20:40:06.825Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '55',
#       'label': 'vivek ramaswamy',
#       'slug': 'vivek-ramaswamy',
#       'publishedAt': '2023-11-02 21:15:02.18+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:15:02.185Z',
#       'updatedAt': '2024-02-11T18:05:57.95Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '704',
#       'label': 'elizabeth warren',
#       'slug': 'elizabeth-warren',
#       'publishedAt': '2023-12-11 20:13:55.031+00',
#       'createdAt': '2023-12-11T20:13:55.095Z',
#       'updatedAt': '2023-12-11T20:13:55.095Z',
#       '_sync': True},
#      {'id': '220',
#       'label': 'kamala harris',
#       'slug': 'kamala-harris',
#       'publishedAt': '2023-11-02 21:38:26.821+00',
#       'createdAt': '2023-11-02T21:38:26.841Z',
#       'updatedAt': '2023-11-02T21:38:26.841Z',
#       '_sync': True},
#      {'id': '100215',
#       'label': 'All',
#       'slug': 'all',
#       'forceShow': False,
#       'updatedAt': '2024-05-30T15:49:47.004061Z',
#       '_sync': False},
#      {'id': '198',
#       'label': 'Breaking News',
#       'slug': 'breaking-news',
#       'forceShow': True,
#       'publishedAt': '2023-11-02 21:34:44.43+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:34:44.447Z',
#       'updatedAt': '2024-06-06T19:29:01.435036Z',
#       '_sync': False,
#       'forceHide': False}],
#     'cyom': False,
#     'competitive': 0.9997750506136119,
#     'pagerDutyNotificationEnabled': False,
#     'approved': True,
#     'clobRewards': [{'id': '442',
#       'conditionId': '0xdd22472e552920b8438158ea7238bfadfa4f736aa4cee91a6b86c39ead110917',
#       'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#       'rewardsAmount': 0,
#       'rewardsDailyRate': 1000,
#       'startDate': '2024-04-05',
#       'endDate': '2500-12-31'}],
#     'rewardsMinSize': 200,
#     'rewardsMaxSpread': 1.5,
#     'spread': 0.002,
#     'oneDayPriceChange': -0.011,
#     'lastTradePrice': 0.517,
#     'bestBid': 0.514,
#     'bestAsk': 0.516,
#     'automaticallyActive': True},
#    {'id': '253592',
#     'question': 'Will Joe Biden win the 2024 US Presidential Election?',
#     'conditionId': '0x14018049e265a2d88f284be9588e2e3542e3a3df08ccdb344d28355dd7fdd8ef',
#     'slug': 'will-joe-biden-win-the-2024-us-presidential-election',
#     'resolutionSource': '',
#     'endDate': '2024-11-05T00:00:00Z',
#     'liquidity': '6920396.73287',
#     'startDate': '2024-01-04T22:58:00Z',
#     'fee': '20000000000000000',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-win-the-2024-us-presidential-election-7eba08de-3d3a-41f1-95f6-fcf36bad1855.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-win-the-2024-us-presidential-election-7eba08de-3d3a-41f1-95f6-fcf36bad1855.png',
#     'description': 'This market will resolve to “Yes” if Joe Biden wins the 2024 US Presidential Election. Otherwise, this market will resolve to “No.”\n\nThe resolution source for this market is the Associated Press, Fox News, and NBC. This market will resolve once all three sources call the race for the same candidate. If all three sources haven’t called the race for the same candidate by the inauguration date (January 20, 2025) this market will resolve based on who is inaugurated.',
#     'outcomes': '["Yes", "No"]',
#     'outcomePrices': '["0.0005", "0.9995"]',
#     'volume': '53633776.558298',
#     'active': True,
#     'marketType': 'normal',
#     'closed': False,
#     'marketMakerAddress': '',
#     'updatedBy': 15,
#     'createdAt': '2024-01-04T17:35:40.9Z',
#     'updatedAt': '2024-08-23T01:10:13.972591Z',
#     'wideFormat': False,
#     'new': False,
#     'featured': False,
#     'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#     'archived': False,
#     'resolvedBy': '0x2F5e3684cb1F318ec51b00Edba38d79Ac2c0aA9d',
#     'restricted': True,
#     'groupItemTitle': 'Joe Biden',
#     'groupItemThreshold': '2',
#     'questionID': '0xe3b1bc389210504ebcb9cffe4b0ed06ccac50561e0f24abb6379984cec030f01',
#     'enableOrderBook': True,
#     'orderPriceMinTickSize': 0.001,
#     'orderMinSize': 5,
#     'volumeNum': 53633776.56,
#     'liquidityNum': 6920396.73,
#     'endDateIso': '2024-11-05',
#     'startDateIso': '2024-01-04',
#     'hasReviewedDates': True,
#     'commentsEnabled': False,
#     'volume24hr': 15631.92,
#     'secondsDelay': 0,
#     'clobTokenIds': '["88027839609243624193415614179328679602612916497045596227438675518749602824929", "34731657770883441140875001518098751138877095477683682718012432921110142479972"]',
#     'umaBond': '99750.0',
#     'umaReward': '500.0',
#     'fpmmLive': True,
#     'volume24hrClob': 15631.92,
#     'volumeClob': 53633776.558298,
#     'liquidityClob': 6920396.73287,
#     'makerBaseFee': 0,
#     'takerBaseFee': 0,
#     'customLiveness': 0,
#     'acceptingOrders': True,
#     'negRisk': True,
#     'negRiskMarketID': '0xe3b1bc389210504ebcb9cffe4b0ed06ccac50561e0f24abb6379984cec030f00',
#     'negRiskRequestID': '0x26417ec7e180076451bc2a40f38dd8478d3e66c18fc57e4aef0e8d11a809f976',
#     'commentCount': 367,
#     'notificationsEnabled': False,
#     '_sync': False,
#     'creator': '',
#     'ready': False,
#     'funded': False,
#     'tags': [{'id': '2',
#       'label': 'Politics',
#       'slug': 'politics',
#       'forceShow': False,
#       'publishedAt': '2023-10-25 18:55:50.674+00',
#       'updatedBy': 13,
#       'createdAt': '2023-10-25T18:55:50.681Z',
#       'updatedAt': '2024-07-05T21:07:05.081707Z',
#       '_sync': False,
#       'forceHide': True},
#      {'id': '1101',
#       'label': 'us presidential election',
#       'slug': 'us-presidential-election',
#       'publishedAt': '2024-02-06 19:42:10.126+00',
#       'createdAt': '2024-02-06T19:42:10.132Z',
#       'updatedAt': '2024-02-06T19:42:10.132Z',
#       '_sync': True},
#      {'id': '15',
#       'label': 'Joe Biden',
#       'slug': 'joe-biden',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:03:39.389+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:03:39.396Z',
#       'updatedAt': '2024-04-24T19:34:18.314621Z',
#       '_sync': False},
#      {'id': '176',
#       'label': 'us elections',
#       'slug': 'us-elections',
#       'publishedAt': '2023-11-02 21:30:44.182+00',
#       'createdAt': '2023-11-02T21:30:44.188Z',
#       'updatedAt': '2023-11-02T21:30:44.188Z',
#       '_sync': True},
#      {'id': '185',
#       'label': '2024 election',
#       'slug': '2024-election',
#       'publishedAt': '2023-11-02 21:31:45.201+00',
#       'createdAt': '2023-11-02T21:31:45.209Z',
#       'updatedAt': '2023-11-02T21:31:45.209Z',
#       '_sync': True},
#      {'id': '1102',
#       'label': '2024 us presidential election',
#       'slug': '2024-us-presidential-election',
#       'publishedAt': '2024-02-06 19:42:21.109+00',
#       'createdAt': '2024-02-06T19:42:21.114Z',
#       'updatedAt': '2024-02-06T19:42:21.114Z',
#       '_sync': True},
#      {'id': '144',
#       'label': 'Elections',
#       'slug': 'elections',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:24:31.008+00',
#       'updatedBy': 13,
#       'createdAt': '2023-11-02T21:24:31.198Z',
#       'updatedAt': '2024-05-03T15:51:20.233636Z',
#       '_sync': False,
#       'forceHide': True},
#      {'id': '187',
#       'label': 'kanye west',
#       'slug': 'kanye-west',
#       'publishedAt': '2023-11-02 21:32:10.391+00',
#       'createdAt': '2023-11-02T21:32:10.407Z',
#       'updatedAt': '2023-11-02T21:32:10.407Z',
#       '_sync': True},
#      {'id': '945',
#       'label': 'michelle obama',
#       'slug': 'michelle-obama',
#       'publishedAt': '2024-02-01 19:15:00.647+00',
#       'createdAt': '2024-02-01T19:15:00.664Z',
#       'updatedAt': '2024-02-01T19:15:00.664Z',
#       '_sync': True},
#      {'id': '382',
#       'label': 'chris christie',
#       'slug': 'chris-christie',
#       'publishedAt': '2023-11-02 22:09:15.517+00',
#       'createdAt': '2023-11-02T22:09:15.535Z',
#       'updatedAt': '2023-11-02T22:09:15.535Z',
#       '_sync': True},
#      {'id': '55',
#       'label': 'vivek ramaswamy',
#       'slug': 'vivek-ramaswamy',
#       'publishedAt': '2023-11-02 21:15:02.18+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:15:02.185Z',
#       'updatedAt': '2024-02-11T18:05:57.95Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '126',
#       'label': 'Trump',
#       'slug': 'trump',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:23:16.384+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:23:16.39Z',
#       'updatedAt': '2024-05-31T01:02:06.643434Z',
#       '_sync': False},
#      {'id': '214',
#       'label': 'hillary clinton',
#       'slug': 'hillary-clinton',
#       'publishedAt': '2023-11-02 21:36:44.111+00',
#       'createdAt': '2023-11-02T21:36:44.126Z',
#       'updatedAt': '2023-11-02T21:36:44.126Z',
#       '_sync': True},
#      {'id': '142',
#       'label': 'nikki haley',
#       'slug': 'nikki-haley',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:24:28.845+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:24:28.852Z',
#       'updatedAt': '2024-02-08T19:46:31.92Z',
#       '_sync': True},
#      {'id': '1103',
#       'label': 'aoc',
#       'slug': 'aoc',
#       'publishedAt': '2024-02-06 19:43:17.999+00',
#       'createdAt': '2024-02-06T19:43:18.005Z',
#       'updatedAt': '2024-02-06T19:43:18.005Z',
#       '_sync': True},
#      {'id': '152',
#       'label': 'democratic party',
#       'slug': 'democratic-party',
#       'publishedAt': '2023-11-02 21:26:09.156+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:26:09.164Z',
#       'updatedAt': '2024-02-11T18:06:11.376Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '57',
#       'label': '2024 presidential election',
#       'slug': '2024-presidential-election',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:15:04.115+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:15:04.125Z',
#       'updatedAt': '2024-02-17T20:40:06.825Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '177',
#       'label': 'gavin newsom',
#       'slug': 'gavin-newsom',
#       'publishedAt': '2023-11-02 21:30:46.001+00',
#       'createdAt': '2023-11-02T21:30:46.018Z',
#       'updatedAt': '2023-11-02T21:30:46.018Z',
#       '_sync': True},
#      {'id': '160',
#       'label': 'ron desantis',
#       'slug': 'ron-desantis',
#       'publishedAt': '2023-11-02 21:27:54.001+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:27:54.02Z',
#       'updatedAt': '2024-03-07T06:56:40.555Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '26',
#       'label': 'republican party',
#       'slug': 'republican-party',
#       'publishedAt': '2023-11-02 21:04:05.072+00',
#       'createdAt': '2023-11-02T21:04:05.078Z',
#       'updatedAt': '2023-11-02T21:04:05.078Z',
#       '_sync': True},
#      {'id': '220',
#       'label': 'kamala harris',
#       'slug': 'kamala-harris',
#       'publishedAt': '2023-11-02 21:38:26.821+00',
#       'createdAt': '2023-11-02T21:38:26.841Z',
#       'updatedAt': '2023-11-02T21:38:26.841Z',
#       '_sync': True},
#      {'id': '360',
#       'label': 'robert f. kennedy jr.',
#       'slug': 'robert-fpt-kennedy-jrpt',
#       'publishedAt': '2023-11-02 22:04:07.269+00',
#       'createdAt': '2023-11-02T22:04:07.284Z',
#       'updatedAt': '2023-11-02T22:04:07.284Z',
#       '_sync': True},
#      {'id': '704',
#       'label': 'elizabeth warren',
#       'slug': 'elizabeth-warren',
#       'publishedAt': '2023-12-11 20:13:55.031+00',
#       'createdAt': '2023-12-11T20:13:55.095Z',
#       'updatedAt': '2023-12-11T20:13:55.095Z',
#       '_sync': True},
#      {'id': '589',
#       'label': 'us presidential election 2024',
#       'slug': 'us-presidential-election-2024',
#       'publishedAt': '2023-11-29 16:29:56.03+00',
#       'createdAt': '2023-11-29T16:29:56.045Z',
#       'updatedAt': '2023-11-29T16:29:56.045Z',
#       '_sync': True},
#      {'id': '1104',
#       'label': 'bernie sanders',
#       'slug': 'bernie-sanders',
#       'publishedAt': '2024-02-06 19:43:33.313+00',
#       'createdAt': '2024-02-06T19:43:33.328Z',
#       'updatedAt': '2024-02-06T19:43:33.328Z',
#       '_sync': True},
#      {'id': '24',
#       'label': 'US Election',
#       'slug': 'us-election',
#       'forceShow': True,
#       'publishedAt': '2023-11-02 21:04:03.712+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:04:03.723Z',
#       'updatedAt': '2024-05-01T17:30:24.691205Z',
#       '_sync': False},
#      {'id': '100215',
#       'label': 'All',
#       'slug': 'all',
#       'forceShow': False,
#       'updatedAt': '2024-05-30T15:49:47.004061Z',
#       '_sync': False},
#      {'id': '198',
#       'label': 'Breaking News',
#       'slug': 'breaking-news',
#       'forceShow': True,
#       'publishedAt': '2023-11-02 21:34:44.43+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:34:44.447Z',
#       'updatedAt': '2024-06-06T19:29:01.435036Z',
#       '_sync': False,
#       'forceHide': False}],
#     'cyom': False,
#     'competitive': 0.8003199679231757,
#     'pagerDutyNotificationEnabled': False,
#     'approved': True,
#     'clobRewards': [{'id': '440',
#       'conditionId': '0x14018049e265a2d88f284be9588e2e3542e3a3df08ccdb344d28355dd7fdd8ef',
#       'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#       'rewardsAmount': 0,
#       'rewardsDailyRate': 30,
#       'startDate': '2024-04-05',
#       'endDate': '2500-12-31'}],
#     'rewardsMinSize': 200,
#     'rewardsMaxSpread': 1.5,
#     'spread': 0.001,
#     'lastTradePrice': 0.001,
#     'bestAsk': 0.001,
#     'automaticallyActive': True},
#    {'id': '253593',
#     'question': 'Will Nikki Haley win the 2024 US Presidential Election?',
#     'conditionId': '0xced9f9d90c94db9f1e1dbd7d9fba82fe4fa7431c0d4e91e28896c8ac2d6acadd',
#     'slug': 'will-nikki-haley-win-the-2024-us-presidential-election',
#     'resolutionSource': '',
#     'endDate': '2024-11-05T00:00:00Z',
#     'liquidity': '3753226.34173',
#     'startDate': '2024-01-04T22:58:00Z',
#     'fee': '20000000000000000',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-nikki-haley-win-the-2024-us-presidential-election-f304eb43-0aac-4548-964b-9819ddc8080c.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-nikki-haley-win-the-2024-us-presidential-election-f304eb43-0aac-4548-964b-9819ddc8080c.png',
#     'description': 'This market will resolve to “Yes” if Nikki Haley wins the 2024 US Presidential Election. Otherwise, this market will resolve to “No.”\n\nThe resolution source for this market is the Associated Press, Fox News, and NBC. This market will resolve once all three sources call the race for the same candidate. If all three sources haven’t called the race for the same candidate by the inauguration date (January 20, 2025) this market will resolve based on who is inaugurated.\n\nNote: An update may be made to this market to allow for early expiration if the candidate is definitively no longer in contention for the presidency.',
#     'outcomes': '["Yes", "No"]',
#     'outcomePrices': '["0.0015", "0.9985"]',
#     'volume': '45613459.748644',
#     'active': True,
#     'marketType': 'normal',
#     'closed': False,
#     'marketMakerAddress': '',
#     'updatedBy': 15,
#     'createdAt': '2024-01-04T17:36:47.96Z',
#     'updatedAt': '2024-08-23T01:08:35.018732Z',
#     'wideFormat': False,
#     'new': False,
#     'featured': False,
#     'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#     'archived': False,
#     'resolvedBy': '0x2F5e3684cb1F318ec51b00Edba38d79Ac2c0aA9d',
#     'restricted': True,
#     'groupItemTitle': 'Nikki Haley',
#     'groupItemThreshold': '6',
#     'questionID': '0xe3b1bc389210504ebcb9cffe4b0ed06ccac50561e0f24abb6379984cec030f02',
#     'enableOrderBook': True,
#     'orderPriceMinTickSize': 0.001,
#     'orderMinSize': 5,
#     'volumeNum': 45613459.75,
#     'liquidityNum': 3753226.34,
#     'endDateIso': '2024-11-05',
#     'startDateIso': '2024-01-04',
#     'hasReviewedDates': True,
#     'commentsEnabled': False,
#     'volume24hr': 1238190.74,
#     'secondsDelay': 0,
#     'clobTokenIds': '["19083349462791593334532840548890602187185739923311385087650426802477691161360", "25663677275476030658483179785762851061160843737234225579491314980654272946621"]',
#     'umaBond': '24750.0',
#     'umaReward': '100.0',
#     'fpmmLive': True,
#     'volume24hrClob': 1238190.740004,
#     'volumeClob': 45613459.748644,
#     'liquidityClob': 3753226.34173,
#     'makerBaseFee': 0,
#     'takerBaseFee': 0,
#     'customLiveness': 0,
#     'acceptingOrders': True,
#     'negRisk': True,
#     'negRiskMarketID': '0xe3b1bc389210504ebcb9cffe4b0ed06ccac50561e0f24abb6379984cec030f00',
#     'negRiskRequestID': '0xa71c59e668b9ad5091ed03858bb6c58e8330602f25abbd08ba8987f0c6d66718',
#     'commentCount': 60,
#     'notificationsEnabled': False,
#     '_sync': False,
#     'creator': '',
#     'ready': False,
#     'funded': False,
#     'tags': [{'id': '142',
#       'label': 'nikki haley',
#       'slug': 'nikki-haley',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:24:28.845+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:24:28.852Z',
#       'updatedAt': '2024-02-08T19:46:31.92Z',
#       '_sync': True},
#      {'id': '1102',
#       'label': '2024 us presidential election',
#       'slug': '2024-us-presidential-election',
#       'publishedAt': '2024-02-06 19:42:21.109+00',
#       'createdAt': '2024-02-06T19:42:21.114Z',
#       'updatedAt': '2024-02-06T19:42:21.114Z',
#       '_sync': True},
#      {'id': '2',
#       'label': 'Politics',
#       'slug': 'politics',
#       'forceShow': False,
#       'publishedAt': '2023-10-25 18:55:50.674+00',
#       'updatedBy': 13,
#       'createdAt': '2023-10-25T18:55:50.681Z',
#       'updatedAt': '2024-07-05T21:07:05.081707Z',
#       '_sync': False,
#       'forceHide': True},
#      {'id': '144',
#       'label': 'Elections',
#       'slug': 'elections',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:24:31.008+00',
#       'updatedBy': 13,
#       'createdAt': '2023-11-02T21:24:31.198Z',
#       'updatedAt': '2024-05-03T15:51:20.233636Z',
#       '_sync': False,
#       'forceHide': True},
#      {'id': '214',
#       'label': 'hillary clinton',
#       'slug': 'hillary-clinton',
#       'publishedAt': '2023-11-02 21:36:44.111+00',
#       'createdAt': '2023-11-02T21:36:44.126Z',
#       'updatedAt': '2023-11-02T21:36:44.126Z',
#       '_sync': True},
#      {'id': '1101',
#       'label': 'us presidential election',
#       'slug': 'us-presidential-election',
#       'publishedAt': '2024-02-06 19:42:10.126+00',
#       'createdAt': '2024-02-06T19:42:10.132Z',
#       'updatedAt': '2024-02-06T19:42:10.132Z',
#       '_sync': True},
#      {'id': '704',
#       'label': 'elizabeth warren',
#       'slug': 'elizabeth-warren',
#       'publishedAt': '2023-12-11 20:13:55.031+00',
#       'createdAt': '2023-12-11T20:13:55.095Z',
#       'updatedAt': '2023-12-11T20:13:55.095Z',
#       '_sync': True},
#      {'id': '177',
#       'label': 'gavin newsom',
#       'slug': 'gavin-newsom',
#       'publishedAt': '2023-11-02 21:30:46.001+00',
#       'createdAt': '2023-11-02T21:30:46.018Z',
#       'updatedAt': '2023-11-02T21:30:46.018Z',
#       '_sync': True},
#      {'id': '185',
#       'label': '2024 election',
#       'slug': '2024-election',
#       'publishedAt': '2023-11-02 21:31:45.201+00',
#       'createdAt': '2023-11-02T21:31:45.209Z',
#       'updatedAt': '2023-11-02T21:31:45.209Z',
#       '_sync': True},
#      {'id': '382',
#       'label': 'chris christie',
#       'slug': 'chris-christie',
#       'publishedAt': '2023-11-02 22:09:15.517+00',
#       'createdAt': '2023-11-02T22:09:15.535Z',
#       'updatedAt': '2023-11-02T22:09:15.535Z',
#       '_sync': True},
#      {'id': '26',
#       'label': 'republican party',
#       'slug': 'republican-party',
#       'publishedAt': '2023-11-02 21:04:05.072+00',
#       'createdAt': '2023-11-02T21:04:05.078Z',
#       'updatedAt': '2023-11-02T21:04:05.078Z',
#       '_sync': True},
#      {'id': '176',
#       'label': 'us elections',
#       'slug': 'us-elections',
#       'publishedAt': '2023-11-02 21:30:44.182+00',
#       'createdAt': '2023-11-02T21:30:44.188Z',
#       'updatedAt': '2023-11-02T21:30:44.188Z',
#       '_sync': True},
#      {'id': '1103',
#       'label': 'aoc',
#       'slug': 'aoc',
#       'publishedAt': '2024-02-06 19:43:17.999+00',
#       'createdAt': '2024-02-06T19:43:18.005Z',
#       'updatedAt': '2024-02-06T19:43:18.005Z',
#       '_sync': True},
#      {'id': '55',
#       'label': 'vivek ramaswamy',
#       'slug': 'vivek-ramaswamy',
#       'publishedAt': '2023-11-02 21:15:02.18+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:15:02.185Z',
#       'updatedAt': '2024-02-11T18:05:57.95Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '24',
#       'label': 'US Election',
#       'slug': 'us-election',
#       'forceShow': True,
#       'publishedAt': '2023-11-02 21:04:03.712+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:04:03.723Z',
#       'updatedAt': '2024-05-01T17:30:24.691205Z',
#       '_sync': False},
#      {'id': '187',
#       'label': 'kanye west',
#       'slug': 'kanye-west',
#       'publishedAt': '2023-11-02 21:32:10.391+00',
#       'createdAt': '2023-11-02T21:32:10.407Z',
#       'updatedAt': '2023-11-02T21:32:10.407Z',
#       '_sync': True},
#      {'id': '945',
#       'label': 'michelle obama',
#       'slug': 'michelle-obama',
#       'publishedAt': '2024-02-01 19:15:00.647+00',
#       'createdAt': '2024-02-01T19:15:00.664Z',
#       'updatedAt': '2024-02-01T19:15:00.664Z',
#       '_sync': True},
#      {'id': '1104',
#       'label': 'bernie sanders',
#       'slug': 'bernie-sanders',
#       'publishedAt': '2024-02-06 19:43:33.313+00',
#       'createdAt': '2024-02-06T19:43:33.328Z',
#       'updatedAt': '2024-02-06T19:43:33.328Z',
#       '_sync': True},
#      {'id': '152',
#       'label': 'democratic party',
#       'slug': 'democratic-party',
#       'publishedAt': '2023-11-02 21:26:09.156+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:26:09.164Z',
#       'updatedAt': '2024-02-11T18:06:11.376Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '15',
#       'label': 'Joe Biden',
#       'slug': 'joe-biden',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:03:39.389+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:03:39.396Z',
#       'updatedAt': '2024-04-24T19:34:18.314621Z',
#       '_sync': False},
#      {'id': '126',
#       'label': 'Trump',
#       'slug': 'trump',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:23:16.384+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:23:16.39Z',
#       'updatedAt': '2024-05-31T01:02:06.643434Z',
#       '_sync': False},
#      {'id': '220',
#       'label': 'kamala harris',
#       'slug': 'kamala-harris',
#       'publishedAt': '2023-11-02 21:38:26.821+00',
#       'createdAt': '2023-11-02T21:38:26.841Z',
#       'updatedAt': '2023-11-02T21:38:26.841Z',
#       '_sync': True},
#      {'id': '360',
#       'label': 'robert f. kennedy jr.',
#       'slug': 'robert-fpt-kennedy-jrpt',
#       'publishedAt': '2023-11-02 22:04:07.269+00',
#       'createdAt': '2023-11-02T22:04:07.284Z',
#       'updatedAt': '2023-11-02T22:04:07.284Z',
#       '_sync': True},
#      {'id': '160',
#       'label': 'ron desantis',
#       'slug': 'ron-desantis',
#       'publishedAt': '2023-11-02 21:27:54.001+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:27:54.02Z',
#       'updatedAt': '2024-03-07T06:56:40.555Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '57',
#       'label': '2024 presidential election',
#       'slug': '2024-presidential-election',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:15:04.115+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:15:04.125Z',
#       'updatedAt': '2024-02-17T20:40:06.825Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '589',
#       'label': 'us presidential election 2024',
#       'slug': 'us-presidential-election-2024',
#       'publishedAt': '2023-11-29 16:29:56.03+00',
#       'createdAt': '2023-11-29T16:29:56.045Z',
#       'updatedAt': '2023-11-29T16:29:56.045Z',
#       '_sync': True},
#      {'id': '100215',
#       'label': 'All',
#       'slug': 'all',
#       'forceShow': False,
#       'updatedAt': '2024-05-30T15:49:47.004061Z',
#       '_sync': False},
#      {'id': '198',
#       'label': 'Breaking News',
#       'slug': 'breaking-news',
#       'forceShow': True,
#       'publishedAt': '2023-11-02 21:34:44.43+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:34:44.447Z',
#       'updatedAt': '2024-06-06T19:29:01.435036Z',
#       '_sync': False,
#       'forceHide': False}],
#     'cyom': False,
#     'competitive': 0.8009597099244316,
#     'pagerDutyNotificationEnabled': False,
#     'approved': True,
#     'clobRewards': [{'id': '451',
#       'conditionId': '0xced9f9d90c94db9f1e1dbd7d9fba82fe4fa7431c0d4e91e28896c8ac2d6acadd',
#       'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#       'rewardsAmount': 0,
#       'rewardsDailyRate': 5,
#       'startDate': '2024-04-05',
#       'endDate': '2500-12-31'}],
#     'rewardsMinSize': 200,
#     'rewardsMaxSpread': 3.5,
#     'spread': 0.001,
#     'oneDayPriceChange': -0.001,
#     'lastTradePrice': 0.001,
#     'bestBid': 0.001,
#     'bestAsk': 0.002,
#     'automaticallyActive': True},
#    {'id': '253594',
#     'question': 'Will Gavin Newsom win the 2024 US Presidential Election?',
#     'conditionId': '0x40bbdd26dc08406eedcb913efee7f7faddf50e16fc21caedb4972d57fd71e0d1',
#     'slug': 'will-gavin-newsom-win-the-2024-us-presidential-election',
#     'resolutionSource': '',
#     'endDate': '2024-11-05T00:00:00Z',
#     'liquidity': '4635837.05267',
#     'startDate': '2024-01-04T23:00:00Z',
#     'fee': '20000000000000000',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-gavin-newsom-win-the-2024-us-presidential-election-1accc79e-527e-4470-b338-c0059bf87185.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-gavin-newsom-win-the-2024-us-presidential-election-1accc79e-527e-4470-b338-c0059bf87185.png',
#     'description': 'This market will resolve to “Yes” if Gavin Newsom wins the 2024 US Presidential Election. Otherwise, this market will resolve to “No.”\n\nThe resolution source for this market is the Associated Press, Fox News, and NBC. This market will resolve once all three sources call the race for the same candidate. If all three sources haven’t called the race for the same candidate by the inauguration date (January 20, 2025) this market will resolve based on who is inaugurated.\n\nNote: An update may be made to this market to allow for early expiration if the candidate is definitively no longer in contention for the presidency.',
#     'outcomes': '["Yes", "No"]',
#     'outcomePrices': '["0.0005", "0.9995"]',
#     'volume': '50378991.338088',
#     'active': True,
#     'marketType': 'normal',
#     'closed': False,
#     'marketMakerAddress': '',
#     'updatedBy': 15,
#     'createdAt': '2024-01-04T17:37:48.563Z',
#     'updatedAt': '2024-08-23T01:08:30.846358Z',
#     'wideFormat': False,
#     'new': False,
#     'featured': False,
#     'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#     'archived': False,
#     'resolvedBy': '0x2F5e3684cb1F318ec51b00Edba38d79Ac2c0aA9d',
#     'restricted': True,
#     'groupItemTitle': 'Gavin Newsom',
#     'groupItemThreshold': '4',
#     'questionID': '0xe3b1bc389210504ebcb9cffe4b0ed06ccac50561e0f24abb6379984cec030f03',
#     'enableOrderBook': True,
#     'orderPriceMinTickSize': 0.001,
#     'orderMinSize': 5,
#     'volumeNum': 50378991.34,
#     'liquidityNum': 4635837.05,
#     'endDateIso': '2024-11-05',
#     'startDateIso': '2024-01-04',
#     'hasReviewedDates': True,
#     'commentsEnabled': False,
#     'volume24hr': 52270,
#     'secondsDelay': 0,
#     'clobTokenIds': '["99200347365169760700385453164878188504479548439905371494493482364634358863823", "88063614818983277039870506697948521713429593096456892435153186054911641634952"]',
#     'umaBond': '24750.0',
#     'umaReward': '100.0',
#     'fpmmLive': True,
#     'volume24hrClob': 52270,
#     'volumeClob': 50378991.338088,
#     'liquidityClob': 4635837.05267,
#     'makerBaseFee': 0,
#     'takerBaseFee': 0,
#     'customLiveness': 0,
#     'acceptingOrders': True,
#     'negRisk': True,
#     'negRiskMarketID': '0xe3b1bc389210504ebcb9cffe4b0ed06ccac50561e0f24abb6379984cec030f00',
#     'negRiskRequestID': '0xa00cfee17591a0363f2efb729f6250912339f61f3fef97d0fc669c830875f875',
#     'commentCount': 39,
#     'notificationsEnabled': False,
#     '_sync': False,
#     'creator': '',
#     'ready': False,
#     'funded': False,
#     'tags': [{'id': '2',
#       'label': 'Politics',
#       'slug': 'politics',
#       'forceShow': False,
#       'publishedAt': '2023-10-25 18:55:50.674+00',
#       'updatedBy': 13,
#       'createdAt': '2023-10-25T18:55:50.681Z',
#       'updatedAt': '2024-07-05T21:07:05.081707Z',
#       '_sync': False,
#       'forceHide': True},
#      {'id': '1101',
#       'label': 'us presidential election',
#       'slug': 'us-presidential-election',
#       'publishedAt': '2024-02-06 19:42:10.126+00',
#       'createdAt': '2024-02-06T19:42:10.132Z',
#       'updatedAt': '2024-02-06T19:42:10.132Z',
#       '_sync': True},
#      {'id': '177',
#       'label': 'gavin newsom',
#       'slug': 'gavin-newsom',
#       'publishedAt': '2023-11-02 21:30:46.001+00',
#       'createdAt': '2023-11-02T21:30:46.018Z',
#       'updatedAt': '2023-11-02T21:30:46.018Z',
#       '_sync': True},
#      {'id': '185',
#       'label': '2024 election',
#       'slug': '2024-election',
#       'publishedAt': '2023-11-02 21:31:45.201+00',
#       'createdAt': '2023-11-02T21:31:45.209Z',
#       'updatedAt': '2023-11-02T21:31:45.209Z',
#       '_sync': True},
#      {'id': '15',
#       'label': 'Joe Biden',
#       'slug': 'joe-biden',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:03:39.389+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:03:39.396Z',
#       'updatedAt': '2024-04-24T19:34:18.314621Z',
#       '_sync': False},
#      {'id': '26',
#       'label': 'republican party',
#       'slug': 'republican-party',
#       'publishedAt': '2023-11-02 21:04:05.072+00',
#       'createdAt': '2023-11-02T21:04:05.078Z',
#       'updatedAt': '2023-11-02T21:04:05.078Z',
#       '_sync': True},
#      {'id': '214',
#       'label': 'hillary clinton',
#       'slug': 'hillary-clinton',
#       'publishedAt': '2023-11-02 21:36:44.111+00',
#       'createdAt': '2023-11-02T21:36:44.126Z',
#       'updatedAt': '2023-11-02T21:36:44.126Z',
#       '_sync': True},
#      {'id': '126',
#       'label': 'Trump',
#       'slug': 'trump',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:23:16.384+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:23:16.39Z',
#       'updatedAt': '2024-05-31T01:02:06.643434Z',
#       '_sync': False},
#      {'id': '142',
#       'label': 'nikki haley',
#       'slug': 'nikki-haley',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:24:28.845+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:24:28.852Z',
#       'updatedAt': '2024-02-08T19:46:31.92Z',
#       '_sync': True},
#      {'id': '1103',
#       'label': 'aoc',
#       'slug': 'aoc',
#       'publishedAt': '2024-02-06 19:43:17.999+00',
#       'createdAt': '2024-02-06T19:43:18.005Z',
#       'updatedAt': '2024-02-06T19:43:18.005Z',
#       '_sync': True},
#      {'id': '704',
#       'label': 'elizabeth warren',
#       'slug': 'elizabeth-warren',
#       'publishedAt': '2023-12-11 20:13:55.031+00',
#       'createdAt': '2023-12-11T20:13:55.095Z',
#       'updatedAt': '2023-12-11T20:13:55.095Z',
#       '_sync': True},
#      {'id': '382',
#       'label': 'chris christie',
#       'slug': 'chris-christie',
#       'publishedAt': '2023-11-02 22:09:15.517+00',
#       'createdAt': '2023-11-02T22:09:15.535Z',
#       'updatedAt': '2023-11-02T22:09:15.535Z',
#       '_sync': True},
#      {'id': '176',
#       'label': 'us elections',
#       'slug': 'us-elections',
#       'publishedAt': '2023-11-02 21:30:44.182+00',
#       'createdAt': '2023-11-02T21:30:44.188Z',
#       'updatedAt': '2023-11-02T21:30:44.188Z',
#       '_sync': True},
#      {'id': '1104',
#       'label': 'bernie sanders',
#       'slug': 'bernie-sanders',
#       'publishedAt': '2024-02-06 19:43:33.313+00',
#       'createdAt': '2024-02-06T19:43:33.328Z',
#       'updatedAt': '2024-02-06T19:43:33.328Z',
#       '_sync': True},
#      {'id': '57',
#       'label': '2024 presidential election',
#       'slug': '2024-presidential-election',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:15:04.115+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:15:04.125Z',
#       'updatedAt': '2024-02-17T20:40:06.825Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '55',
#       'label': 'vivek ramaswamy',
#       'slug': 'vivek-ramaswamy',
#       'publishedAt': '2023-11-02 21:15:02.18+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:15:02.185Z',
#       'updatedAt': '2024-02-11T18:05:57.95Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '187',
#       'label': 'kanye west',
#       'slug': 'kanye-west',
#       'publishedAt': '2023-11-02 21:32:10.391+00',
#       'createdAt': '2023-11-02T21:32:10.407Z',
#       'updatedAt': '2023-11-02T21:32:10.407Z',
#       '_sync': True},
#      {'id': '589',
#       'label': 'us presidential election 2024',
#       'slug': 'us-presidential-election-2024',
#       'publishedAt': '2023-11-29 16:29:56.03+00',
#       'createdAt': '2023-11-29T16:29:56.045Z',
#       'updatedAt': '2023-11-29T16:29:56.045Z',
#       '_sync': True},
#      {'id': '160',
#       'label': 'ron desantis',
#       'slug': 'ron-desantis',
#       'publishedAt': '2023-11-02 21:27:54.001+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:27:54.02Z',
#       'updatedAt': '2024-03-07T06:56:40.555Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '152',
#       'label': 'democratic party',
#       'slug': 'democratic-party',
#       'publishedAt': '2023-11-02 21:26:09.156+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:26:09.164Z',
#       'updatedAt': '2024-02-11T18:06:11.376Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '144',
#       'label': 'Elections',
#       'slug': 'elections',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:24:31.008+00',
#       'updatedBy': 13,
#       'createdAt': '2023-11-02T21:24:31.198Z',
#       'updatedAt': '2024-05-03T15:51:20.233636Z',
#       '_sync': False,
#       'forceHide': True},
#      {'id': '360',
#       'label': 'robert f. kennedy jr.',
#       'slug': 'robert-fpt-kennedy-jrpt',
#       'publishedAt': '2023-11-02 22:04:07.269+00',
#       'createdAt': '2023-11-02T22:04:07.284Z',
#       'updatedAt': '2023-11-02T22:04:07.284Z',
#       '_sync': True},
#      {'id': '1102',
#       'label': '2024 us presidential election',
#       'slug': '2024-us-presidential-election',
#       'publishedAt': '2024-02-06 19:42:21.109+00',
#       'createdAt': '2024-02-06T19:42:21.114Z',
#       'updatedAt': '2024-02-06T19:42:21.114Z',
#       '_sync': True},
#      {'id': '24',
#       'label': 'US Election',
#       'slug': 'us-election',
#       'forceShow': True,
#       'publishedAt': '2023-11-02 21:04:03.712+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:04:03.723Z',
#       'updatedAt': '2024-05-01T17:30:24.691205Z',
#       '_sync': False},
#      {'id': '945',
#       'label': 'michelle obama',
#       'slug': 'michelle-obama',
#       'publishedAt': '2024-02-01 19:15:00.647+00',
#       'createdAt': '2024-02-01T19:15:00.664Z',
#       'updatedAt': '2024-02-01T19:15:00.664Z',
#       '_sync': True},
#      {'id': '220',
#       'label': 'kamala harris',
#       'slug': 'kamala-harris',
#       'publishedAt': '2023-11-02 21:38:26.821+00',
#       'createdAt': '2023-11-02T21:38:26.841Z',
#       'updatedAt': '2023-11-02T21:38:26.841Z',
#       '_sync': True},
#      {'id': '100215',
#       'label': 'All',
#       'slug': 'all',
#       'forceShow': False,
#       'updatedAt': '2024-05-30T15:49:47.004061Z',
#       '_sync': False},
#      {'id': '198',
#       'label': 'Breaking News',
#       'slug': 'breaking-news',
#       'forceShow': True,
#       'publishedAt': '2023-11-02 21:34:44.43+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:34:44.447Z',
#       'updatedAt': '2024-06-06T19:29:01.435036Z',
#       '_sync': False,
#       'forceHide': False}],
#     'cyom': False,
#     'competitive': 0.8003199679231757,
#     'pagerDutyNotificationEnabled': False,
#     'approved': True,
#     'clobRewards': [{'id': '445',
#       'conditionId': '0x40bbdd26dc08406eedcb913efee7f7faddf50e16fc21caedb4972d57fd71e0d1',
#       'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#       'rewardsAmount': 0,
#       'rewardsDailyRate': 5,
#       'startDate': '2024-04-05',
#       'endDate': '2500-12-31'}],
#     'rewardsMinSize': 200,
#     'rewardsMaxSpread': 3.5,
#     'spread': 0.001,
#     'lastTradePrice': 0.001,
#     'bestAsk': 0.001,
#     'automaticallyActive': True},
#    {'id': '253595',
#     'question': 'Will Robert F. Kennedy Jr. win the 2024 US Presidential Election?',
#     'conditionId': '0x7da35195ac3c7bf167f88ab0c27067a99020e36de67d39968b71d9debcdd925e',
#     'slug': 'will-robert-f-kennedy-jr-win-the-2024-us-presidential-election',
#     'resolutionSource': '',
#     'endDate': '2024-11-04T12:00:00Z',
#     'liquidity': '2861968.76923',
#     'startDate': '2024-01-04T23:01:00Z',
#     'fee': '20000000000000000',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-robert-f-kennedy-jr-win-the-2024-us-presidential-election-KQ7jJxF2dPpA.jpg',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-robert-f-kennedy-jr-win-the-2024-us-presidential-election-KQ7jJxF2dPpA.jpg',
# ...
#     'negRiskRequestID': '0x2fe69884e5e44c9c91e535e4c559a8001339b0a5b379263a60b0e8b814b3d5c3',
#     'commentCount': 26,
#     'notificationsEnabled': True,
#     '_sync': False,
#     'creator': '',
#     'ready': False,
#     'funded': False,
#     'tags': [{'id': '53',
#       'label': 'Movies',
#       'slug': 'movies',
#       'forceShow': True,
#       'publishedAt': '2023-11-02 21:14:39.573+00',
#       'createdAt': '2023-11-02T21:14:39.577Z',
#       'updatedAt': '2024-05-08T22:11:38.167995Z',
#       '_sync': False},
#      {'id': '51',
#       'label': 'box office',
#       'slug': 'box-office',
#       'forceShow': False,
#       'publishedAt': '2023-11-02 21:14:38.309+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:14:38.316Z',
#       'updatedAt': '2024-03-09T07:27:10.66Z',
#       '_sync': True},
#      {'id': '315',
#       'label': 'entertainment',
#       'slug': 'entertainment',
#       'publishedAt': '2023-11-02 21:53:56.665+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:53:56.686Z',
#       'updatedAt': '2024-02-11T18:13:15.266Z',
#       '_sync': True,
#       'forceHide': True},
#      {'id': '52',
#       'label': 'film industry',
#       'slug': 'film-industry',
#       'publishedAt': '2023-11-02 21:14:38.92+00',
#       'createdAt': '2023-11-02T21:14:38.925Z',
#       'updatedAt': '2023-11-02T21:14:38.925Z',
#       '_sync': True},
#      {'id': '596',
#       'label': 'Pop Culture',
#       'slug': 'pop-culture',
#       'forceShow': False,
#       'publishedAt': '2023-11-29 18:40:13.013+00',
#       'createdAt': '2023-11-29T18:40:14.63Z',
#       'updatedAt': '2024-07-05T21:07:18.534077Z',
#       '_sync': False},
#      {'id': '1158',
#       'label': 'joker 2',
#       'slug': 'joker-2',
#       'publishedAt': '2024-02-06 19:52:44.782+00',
#       'createdAt': '2024-02-06T19:52:44.798Z',
#       'updatedAt': '2024-02-06T19:52:44.798Z',
#       '_sync': True},
#      {'id': '1162',
#       'label': 'inside out 2',
#       'slug': 'inside-out-2',
#       'publishedAt': '2024-02-06 19:53:10.101+00',
#       'createdAt': '2024-02-06T19:53:10.117Z',
#       'updatedAt': '2024-02-06T19:53:10.117Z',
#       '_sync': True},
#      {'id': '1159',
#       'label': 'mad max saga',
#       'slug': 'mad-max-saga',
#       'publishedAt': '2024-02-06 19:52:54.007+00',
#       'createdAt': '2024-02-06T19:52:54.025Z',
#       'updatedAt': '2024-02-06T19:52:54.025Z',
#       '_sync': True},
#      {'id': '1161',
#       'label': 'despicable me 4',
#       'slug': 'despicable-me-4',
#       'publishedAt': '2024-02-06 19:53:01.778+00',
#       'createdAt': '2024-02-06T19:53:01.785Z',
#       'updatedAt': '2024-02-06T19:53:01.785Z',
#       '_sync': True},
#      {'id': '1164',
#       'label': 'hollywood',
#       'slug': 'hollywood',
#       'publishedAt': '2024-02-06 19:53:10.498+00',
#       'createdAt': '2024-02-06T19:53:10.52Z',
#       'updatedAt': '2024-02-06T19:53:10.52Z',
#       '_sync': True},
#      {'id': '1155',
#       'label': 'deadpool 3',
#       'slug': 'deadpool-3',
#       'publishedAt': '2024-02-06 19:52:24.253+00',
#       'createdAt': '2024-02-06T19:52:24.285Z',
#       'updatedAt': '2024-02-06T19:52:24.285Z',
#       '_sync': True},
#      {'id': '1157',
#       'label': 'dune: part 2',
#       'slug': 'dune-part-2',
#       'publishedAt': '2024-02-06 19:52:32.782+00',
#       'createdAt': '2024-02-06T19:52:32.788Z',
#       'updatedAt': '2024-02-06T19:52:32.788Z',
#       '_sync': True},
#      {'id': '120',
#       'label': 'finance',
#       'slug': 'finance',
#       'publishedAt': '2023-11-02 21:22:21.615+00',
#       'createdAt': '2023-11-02T21:22:21.62Z',
#       'updatedAt': '2023-11-02T21:22:21.62Z',
#       '_sync': True},
#      {'id': '1160',
#       'label': 'furiosa',
#       'slug': 'furiosa',
#       'publishedAt': '2024-02-06 19:52:54.274+00',
#       'createdAt': '2024-02-06T19:52:54.293Z',
#       'updatedAt': '2024-02-06T19:52:54.293Z',
#       '_sync': True},
#      {'id': '1156',
#       'label': 'movie gross',
#       'slug': 'movie-gross',
#       'publishedAt': '2024-02-06 19:52:32.445+00',
#       'createdAt': '2024-02-06T19:52:32.451Z',
#       'updatedAt': '2024-02-06T19:52:32.451Z',
#       '_sync': True},
#      {'id': '1163',
#       'label': 'animation',
#       'slug': 'animation',
#       'publishedAt': '2024-02-06 19:53:10.174+00',
#       'createdAt': '2024-02-06T19:53:10.179Z',
#       'updatedAt': '2024-02-06T19:53:10.179Z',
#       '_sync': True},
#      {'id': '100215',
#       'label': 'All',
#       'slug': 'all',
#       'forceShow': False,
#       'updatedAt': '2024-05-30T15:49:47.004061Z',
#       '_sync': False}],
#     'cyom': False,
#     'competitive': 0.8530785472072341,
#     'pagerDutyNotificationEnabled': False,
#     'approved': True,
#     'clobRewards': [{'id': '298',
#       'conditionId': '0xaa69f9c948b8a162eb305285bf31a581868c23a289573889b27361726c213b64',
#       'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#       'rewardsAmount': 0,
#       'rewardsDailyRate': 10,
#       'startDate': '2024-04-05',
#       'endDate': '2500-12-31'}],
#     'rewardsMinSize': 200,
#     'rewardsMaxSpread': 3.5,
#     'spread': 0.01,
#     'lastTradePrice': 0.08,
#     'bestBid': 0.08,
#     'bestAsk': 0.09,
#     'automaticallyActive': True}],
#   'tags': [{'id': '53',
#     'label': 'Movies',
#     'slug': 'movies',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:14:39.573+00',
#     'createdAt': '2023-11-02T21:14:39.577Z',
#     'updatedAt': '2024-05-08T22:11:38.167995Z',
#     '_sync': False},
#    {'id': '1155',
#     'label': 'deadpool 3',
#     'slug': 'deadpool-3',
#     'publishedAt': '2024-02-06 19:52:24.253+00',
#     'createdAt': '2024-02-06T19:52:24.285Z',
#     'updatedAt': '2024-02-06T19:52:24.285Z',
#     '_sync': True},
#    {'id': '51',
#     'label': 'box office',
#     'slug': 'box-office',
#     'forceShow': False,
#     'publishedAt': '2023-11-02 21:14:38.309+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:14:38.316Z',
#     'updatedAt': '2024-03-09T07:27:10.66Z',
#     '_sync': True},
#    {'id': '315',
#     'label': 'entertainment',
#     'slug': 'entertainment',
#     'publishedAt': '2023-11-02 21:53:56.665+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:53:56.686Z',
#     'updatedAt': '2024-02-11T18:13:15.266Z',
#     '_sync': True,
#     'forceHide': True},
#    {'id': '120',
#     'label': 'finance',
#     'slug': 'finance',
#     'publishedAt': '2023-11-02 21:22:21.615+00',
#     'createdAt': '2023-11-02T21:22:21.62Z',
#     'updatedAt': '2023-11-02T21:22:21.62Z',
#     '_sync': True},
#    {'id': '1157',
#     'label': 'dune: part 2',
#     'slug': 'dune-part-2',
#     'publishedAt': '2024-02-06 19:52:32.782+00',
#     'createdAt': '2024-02-06T19:52:32.788Z',
#     'updatedAt': '2024-02-06T19:52:32.788Z',
#     '_sync': True},
#    {'id': '1156',
#     'label': 'movie gross',
#     'slug': 'movie-gross',
#     'publishedAt': '2024-02-06 19:52:32.445+00',
#     'createdAt': '2024-02-06T19:52:32.451Z',
#     'updatedAt': '2024-02-06T19:52:32.451Z',
#     '_sync': True},
#    {'id': '52',
#     'label': 'film industry',
#     'slug': 'film-industry',
#     'publishedAt': '2023-11-02 21:14:38.92+00',
#     'createdAt': '2023-11-02T21:14:38.925Z',
#     'updatedAt': '2023-11-02T21:14:38.925Z',
#     '_sync': True},
#    {'id': '1158',
#     'label': 'joker 2',
#     'slug': 'joker-2',
#     'publishedAt': '2024-02-06 19:52:44.782+00',
#     'createdAt': '2024-02-06T19:52:44.798Z',
#     'updatedAt': '2024-02-06T19:52:44.798Z',
#     '_sync': True},
#    {'id': '1160',
#     'label': 'furiosa',
#     'slug': 'furiosa',
#     'publishedAt': '2024-02-06 19:52:54.274+00',
#     'createdAt': '2024-02-06T19:52:54.293Z',
#     'updatedAt': '2024-02-06T19:52:54.293Z',
#     '_sync': True},
#    {'id': '1159',
#     'label': 'mad max saga',
#     'slug': 'mad-max-saga',
#     'publishedAt': '2024-02-06 19:52:54.007+00',
#     'createdAt': '2024-02-06T19:52:54.025Z',
#     'updatedAt': '2024-02-06T19:52:54.025Z',
#     '_sync': True},
#    {'id': '1161',
#     'label': 'despicable me 4',
#     'slug': 'despicable-me-4',
#     'publishedAt': '2024-02-06 19:53:01.778+00',
#     'createdAt': '2024-02-06T19:53:01.785Z',
#     'updatedAt': '2024-02-06T19:53:01.785Z',
#     '_sync': True},
#    {'id': '1162',
#     'label': 'inside out 2',
#     'slug': 'inside-out-2',
#     'publishedAt': '2024-02-06 19:53:10.101+00',
#     'createdAt': '2024-02-06T19:53:10.117Z',
#     'updatedAt': '2024-02-06T19:53:10.117Z',
#     '_sync': True},
#    {'id': '1163',
#     'label': 'animation',
#     'slug': 'animation',
#     'publishedAt': '2024-02-06 19:53:10.174+00',
#     'createdAt': '2024-02-06T19:53:10.179Z',
#     'updatedAt': '2024-02-06T19:53:10.179Z',
#     '_sync': True},
#    {'id': '1164',
#     'label': 'hollywood',
#     'slug': 'hollywood',
#     'publishedAt': '2024-02-06 19:53:10.498+00',
#     'createdAt': '2024-02-06T19:53:10.52Z',
#     'updatedAt': '2024-02-06T19:53:10.52Z',
#     '_sync': True},
#    {'id': '596',
#     'label': 'Pop Culture',
#     'slug': 'pop-culture',
#     'forceShow': False,
#     'publishedAt': '2023-11-29 18:40:13.013+00',
#     'createdAt': '2023-11-29T18:40:14.63Z',
#     'updatedAt': '2024-07-05T21:07:18.534077Z',
#     '_sync': False},
#    {'id': '100215',
#     'label': 'All',
#     'slug': 'all',
#     'forceShow': False,
#     'updatedAt': '2024-05-30T15:49:47.004061Z',
#     '_sync': False}],
#   'cyom': False,
#   'showAllOutcomes': True,
#   'showMarketImages': True,
#   'enableNegRisk': True,
#   'automaticallyActive': True},
#  {'id': '11797',
#   'ticker': 'will-kamala-drop-out-in-august',
#   'slug': 'will-kamala-drop-out-in-august',
#   'title': 'Will Kamala Harris drop out in August?',
#   'description': 'This market will resolve to "Yes" if Kamala Harris officially announces her withdrawal or is confirmed to have withdrawn from the 2024 US presidential race between August 1, 2024, 12:00 AM ET, and August 31, 2024, 11:59 PM ET. \n\nIn the event of any extenuating circumstances that prevent Kamala Harris from continuing the race, this market will also resolve to "Yes".\n\nIf Kamala Harris does not announce her withdrawal or is not forced to withdraw from the 2024 presidential race by the specified time, this market will resolve to "No".\n\nThe primary resolution source for this market will be official information from Kamala Harris or her official/legal representatives, however a consensus of credible reporting will also be used.\n\n',
#   'startDate': '2024-07-31T20:51:09.235182Z',
#   'creationDate': '2024-07-31T20:51:09.235178Z',
#   'endDate': '2024-08-31T12:00:00Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-kamala-drop-out-in-august-Kqu-PkCiyICz.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-kamala-drop-out-in-august-Kqu-PkCiyICz.jpg',
#   'active': True,
#   'closed': False,
#   'archived': False,
#   'new': False,
#   'featured': False,
#   'restricted': True,
#   'liquidity': 312825.55997,
#   'volume': 3283497.439875,
#   'createdAt': '2024-07-31T20:43:29.48298Z',
#   'updatedAt': '2024-08-23T01:09:11.792713Z',
#   'competitive': 0.8022384055993032,
#   'volume24hr': 143100.65,
#   'enableOrderBook': True,
#   'liquidityClob': 312825.55997,
#   '_sync': False,
#   'commentCount': 17,
#   'markets': [{'id': '504399',
#     'question': 'Will Kamala Harris drop out in August?',
#     'conditionId': '0x05f242284d310c0face95345a008e80a530d41a706ccddf47167a7ebf6b76717',
#     'slug': 'will-kamala-drop-out-in-august',
#     'resolutionSource': '',
#     'endDate': '2024-08-31T12:00:00Z',
#     'liquidity': '312825.55997',
#     'startDate': '2024-08-07T14:03:18.889Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-kamala-drop-out-in-august-Kqu-PkCiyICz.jpg',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-kamala-drop-out-in-august-Kqu-PkCiyICz.jpg',
#     'description': 'This market will resolve to "Yes" if Kamala Harris officially announces her withdrawal or is confirmed to have withdrawn from the 2024 US presidential race between August 1, 2024, 12:00 AM ET, and August 31, 2024, 11:59 PM ET. \n\nIn the event of any extenuating circumstances that prevent Kamala Harris from continuing the race, this market will also resolve to "Yes".\n\nIf Kamala Harris does not announce her withdrawal or is not forced to withdraw from the 2024 presidential race by the specified time, this market will resolve to "No".\n\nThe primary resolution source for this market will be official information from Kamala Harris or her official/legal representatives, however a consensus of credible reporting will also be used.\n\n',
#     'outcomes': '["Yes", "No"]',
#     'outcomePrices': '["0.0035", "0.9965"]',
#     'volume': '3283497.439875',
#     'active': True,
#     'closed': False,
#     'marketMakerAddress': '',
#     'createdAt': '2024-07-31T20:43:31.317387Z',
#     'updatedAt': '2024-08-23T01:08:46.302492Z',
#     'new': False,
#     'featured': False,
#     'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#     'archived': False,
#     'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74',
#     'restricted': True,
#     'groupItemTitle': '',
#     'groupItemThreshold': '0',
#     'questionID': '0xcf3ac9a885cb8afdae7f3e39d947a91ba69a73fbe261bb1348dc1807c25b7d7e',
#     'enableOrderBook': True,
#     'orderPriceMinTickSize': 0.001,
#     'orderMinSize': 5,
#     'volumeNum': 3283497.44,
#     'liquidityNum': 312825.56,
#     'endDateIso': '2024-08-31',
#     'startDateIso': '2024-08-07',
#     'hasReviewedDates': True,
#     'volume24hr': 143100.65,
#     'clobTokenIds': '["102421387815191237331738744683995773684216429951408994781603999297405288616223", "30494108772513425001849192872617529159869609016840347957113911572325085864031"]',
#     'umaBond': '500',
#     'umaReward': '5',
#     'volume24hrClob': 143100.650133,
#     'volumeClob': 3283497.439875,
#     'liquidityClob': 312825.55997,
#     'acceptingOrders': True,
#     'negRisk': False,
#     'commentCount': 17,
#     '_sync': False,
#     'ready': False,
#     'funded': False,
#     'acceptingOrdersTimestamp': '2024-07-31T20:49:26Z',
#     'tags': [{'id': '100291',
#       'label': 'Kamala',
#       'slug': 'kamala',
#       'createdAt': '2024-07-03T16:53:53.477357Z',
#       '_sync': False},
#      {'id': '24',
#       'label': 'US Election',
#       'slug': 'us-election',
#       'forceShow': True,
#       'publishedAt': '2023-11-02 21:04:03.712+00',
#       'updatedBy': 15,
#       'createdAt': '2023-11-02T21:04:03.723Z',
#       'updatedAt': '2024-05-01T17:30:24.691205Z',
#       '_sync': False},
#      {'id': '2',
#       'label': 'Politics',
#       'slug': 'politics',
#       'forceShow': False,
#       'publishedAt': '2023-10-25 18:55:50.674+00',
#       'updatedBy': 13,
#       'createdAt': '2023-10-25T18:55:50.681Z',
#       'updatedAt': '2024-07-05T21:07:05.081707Z',
#       '_sync': False,
#       'forceHide': True}],
#     'cyom': False,
#     'competitive': 0.8022384055993032,
#     'pagerDutyNotificationEnabled': False,
#     'approved': True,
#     'clobRewards': [{'id': '3823',
#       'conditionId': '0x05f242284d310c0face95345a008e80a530d41a706ccddf47167a7ebf6b76717',
#       'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#       'rewardsAmount': 0,
#       'rewardsDailyRate': 20,
#       'startDate': '2024-07-31',
#       'endDate': '2500-12-31'}],
#     'rewardsMinSize': 100,
#     'rewardsMaxSpread': 3.5,
#     'spread': 0.001,
#     'oneDayPriceChange': -0.002,
#     'lastTradePrice': 0.004,
#     'bestBid': 0.003,
#     'bestAsk': 0.004,
#     'automaticallyActive': True}],
#   'tags': [{'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True}],
#   'cyom': False,
#   'showAllOutcomes': True,
#   'showMarketImages': True,
#   'enableNegRisk': False,
#   'automaticallyActive': True}]

# %% [markdown]
# # Filter on Events Containing Kamala
#
# Now we don't want to bet on everything, let's select something we're interested in at this time. Going to filter on those that have 'Kamala' in the title of the event.

# %%
kamala_events = {}
for event in response:
  if 'Kamala' in event['title']:
    print(event)
    kamala_events[event['id']] = event
# Out:
# {'id': '11906', 'ticker': 'kamala-swap-at-dnc', 'slug': 'kamala-swap-at-dnc', 'title': 'Kamala Harris replaced as nominee at DNC?', 'description': 'This market will resolve to "Yes" if Kamala Harris is confirmed to have been replaced or withdraws as the nominee of the Democratic Party at the Democratic National Convention (DNC). Otherwise, this market will resolve to "No". \n\nIf Harris is confirmed to have been replaced or withdraws as the nominee before the DNC this market will also resolve to "Yes."\n\nIf the DNC has concluded and Kamala Harris remains the nominee, this market will resolve to "No." If the DNC is cancelled or rescheduled to a date after November 4, 2024, 11:59 PM ET, this market will resolve to "No".\n\nThe primary resolution source for this market will be information from the Democratic Party and footage from the DNC, however a consensus of credible reporting will also be used.\n', 'startDate': '2024-08-07T16:54:51.88882Z', 'creationDate': '2024-08-07T16:54:51.888818Z', 'endDate': '2024-08-22T12:00:00Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/kamala-swap-at-dnc-oKtmA_X2zJV7.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/kamala-swap-at-dnc-oKtmA_X2zJV7.jpg', 'active': True, 'closed': False, 'archived': False, 'new': False, 'featured': False, 'restricted': True, 'liquidity': 455080.80633, 'volume': 15472385.259402, 'createdAt': '2024-08-07T16:16:51.476408Z', 'updatedAt': '2024-08-23T01:09:11.208313Z', 'competitive': 0.8012794830785799, 'volume24hr': 1079695.31, 'enableOrderBook': True, 'liquidityClob': 455080.80633, '_sync': False, 'commentCount': 183, 'markets': [{'id': '504653', 'question': 'Kamala Harris replaced as nominee at DNC?', 'conditionId': '0x4aa64e62f39f54545369c372da7de8bfc6b2e178b5c0f121a0177a225eca9eeb', 'slug': 'kamala-swap-at-dnc', 'resolutionSource': '', 'endDate': '2024-08-22T12:00:00Z', 'liquidity': '455080.80633', 'startDate': '2024-08-08T16:38:18.386Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/kamala-swap-at-dnc-oKtmA_X2zJV7.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/kamala-swap-at-dnc-oKtmA_X2zJV7.jpg', 'description': 'This market will resolve to "Yes" if Kamala Harris is confirmed to have been replaced or withdraws as the nominee of the Democratic Party at the Democratic National Convention (DNC). Otherwise, this market will resolve to "No". \n\nIf Harris is confirmed to have been replaced or withdraws as the nominee before the DNC this market will also resolve to "Yes."\n\nIf the DNC has concluded and Kamala Harris remains the nominee, this market will resolve to "No." If the DNC is cancelled or rescheduled to a date after November 4, 2024, 11:59 PM ET, this market will resolve to "No".\n\nThe primary resolution source for this market will be information from the Democratic Party and footage from the DNC, however a consensus of credible reporting will also be used.\n', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.002", "0.998"]', 'volume': '15472386.260402', 'active': True, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-08-07T16:16:52.663796Z', 'updatedAt': '2024-08-23T01:10:12.736907Z', 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74', 'restricted': True, 'groupItemTitle': '', 'groupItemThreshold': '0', 'questionID': '0xfbef242a914178a3c2c7a3852a5ba9e32eef495ae573a25afb7fe1944e34a6c7', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.001, 'orderMinSize': 5, 'volumeNum': 15472386.26, 'liquidityNum': 455080.81, 'endDateIso': '2024-08-22', 'startDateIso': '2024-08-08', 'hasReviewedDates': True, 'volume24hr': 1079696.31, 'clobTokenIds': '["18486927959558081895747033762162733276048973647038256896960790179203889433478", "56246676161526247840185104257368152967669758961175157001660566845073842944135"]', 'umaBond': '500', 'umaReward': '5', 'volume24hrClob' ...
# {'id': '12088', 'ticker': 'what-will-kamala-say-during-acceptance-speech', 'slug': 'what-will-kamala-say-during-acceptance-speech', 'title': 'What will Kamala say during DNC acceptance speech?', 'description': 'This is a market group on what words Kamala Harris will say during her acceptance speech for her nomination as Democratic candidate for President of the United States.', 'startDate': '2024-08-16T23:45:05.893942Z', 'creationDate': '2024-08-16T23:45:05.893935Z', 'endDate': '2024-08-22T12:00:00Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg', 'active': True, 'closed': False, 'archived': False, 'new': False, 'featured': True, 'restricted': True, 'liquidity': 193982.63457, 'volume': 1876211.178971, 'openInterest': 0, 'createdAt': '2024-08-16T21:29:11.44726Z', 'updatedAt': '2024-08-23T01:09:08.880631Z', 'competitive': 0.9991008092716555, 'volume24hr': 716386.17, 'enableOrderBook': True, 'liquidityClob': 193982.63457, '_sync': False, 'negRisk': False, 'commentCount': 295, 'markets': [{'id': '505244', 'question': 'Will Kamala Harris say "Couch" during DNC speech?', 'conditionId': '', 'slug': 'will-kamala-harris-say-couch-during-dnc-speech', 'resolutionSource': '', 'endDate': '2024-08-22T12:00:00Z', 'liquidity': '0', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg', 'description': 'This market will resolve to "Yes" if Kamala Harris says "couch" during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word regardless of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count.\n\nCompound words will count as long as "couch" is part of the compound word and references the meaning which refers to a piece of furniture primarily used for sitting on.\n\nThe resolution source will be the video of the speech.', 'outcomes': '["Yes", "No"]', 'volume': '0', 'active': False, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-08-16T22:08:54.765715Z', 'updatedAt': '2024-08-21T19:35:36.957879Z', 'new': False, 'featured': False, 'submitted_by': '', 'archived': False, 'restricted': True, 'groupItemTitle': 'Couch', 'groupItemThreshold': '16', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.01, 'orderMinSize': 5, 'volumeNum': 0, 'liquidityNum': 0, 'volume24hr': 0, 'umaBond': '500', 'umaReward': '5', 'volume24hrAmm': 0, 'volume24hrClob': 0, 'volumeAmm': 0, 'volumeClob': 0, 'liquidityAmm': 0, 'liquidityClob': 0, 'negRisk': False, '_sync': False, 'ready': False, 'funded': False, 'tags': [{'id': '24', 'label': 'US Election', 'slug': 'us-election', 'forceShow': True, 'publishedAt': '2023-11-02 21:04:03.712+00', 'updatedBy': 15, 'createdAt': '2023-11-02T21:04:03.723Z', 'updatedAt': '2024-05-01T17:30:24.691205Z', '_sync': False}, {'id': '2', 'label': 'Politics', 'slug': 'politics', 'forceShow': False, 'publishedAt': '2023-10-25 18:55:50.674+00', 'updatedBy': 13, 'createdAt': '2023-10-25T18:55:50.681Z', 'updatedAt': '2024-07-05T21:07:05.081707Z', '_sync': False, 'forceHide': True}, {'id': '100334', 'label': 'DNC', 'slug': 'dnc', 'forceShow': False, 'createdAt': '2024-08-08T17:23:09.325012Z', '_sync': False}, {'id': '100291', 'label': 'Kamala', 'slug': 'kamala', 'createdAt': '2024-07-03T16:53:53.477357Z', '_sync': False}, {'id': '100343', 'label': 'Mention Markets', 'slug': 'mention-markets', 'forceShow': False, 'createdAt': '2024-08-16T02:29:11.548984Z', '_sync': False}], 'cyom': F ...
# {'id': '12090', 'ticker': 'how-long-will-kamala-harriss-dnc-speech-be', 'slug': 'how-long-will-kamala-harriss-dnc-speech-be', 'title': "How long will Kamala Harris's DNC speech be?", 'description': "How long will Kamala Harris's DNC speech be?", 'startDate': '2024-08-19T19:05:02.451748Z', 'creationDate': '2024-08-19T19:05:02.451741Z', 'endDate': '2024-08-22T12:00:00Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/how-long-will-kamala-harriss-dnc-speech-be-hSSqiRWYdunw.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/how-long-will-kamala-harriss-dnc-speech-be-hSSqiRWYdunw.jpg', 'active': True, 'closed': False, 'archived': False, 'new': False, 'featured': False, 'restricted': True, 'liquidity': 47600.75466, 'volume': 342075.52677, 'openInterest': 0, 'createdAt': '2024-08-19T13:07:18.191056Z', 'updatedAt': '2024-08-23T01:09:08.495827Z', 'competitive': 0.9979790923380155, 'volume24hr': 150598.61, 'enableOrderBook': True, 'liquidityClob': 47600.75466, '_sync': False, 'negRisk': True, 'negRiskMarketID': '0xeb5d197b786acdc43d91ceafcdc5eaf95ba47c85d16b26c77f7bdda904929200', 'commentCount': 57, 'markets': [{'id': '505274', 'question': 'Kamala Harris DNC speech under 30 minutes?', 'conditionId': '0xfcebd42e5d8a18bc4ac058ae6581384ef459e2459161b7b9c8c5140aa7743108', 'slug': 'kamala-harris-dnc-speech-under-30-minutes', 'resolutionSource': '', 'endDate': '2024-08-22T12:00:00Z', 'liquidity': '6496.2322', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/how-long-will-kamala-harriss-dnc-speech-be-hSSqiRWYdunw.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/how-long-will-kamala-harriss-dnc-speech-be-hSSqiRWYdunw.jpg', 'description': 'This market will resolve to "Yes" if Kamala Harris\'s acceptance speech at the Democratic National Convention (DNC) is less than 30 minutes in length. Otherwise this market will resolve to "No".\n\nIf Kamala Harris does not give a speech at the DNC this market will resolve to "Yes".  \n\nThe speech length will be measured from the start of when Harris begins audibly speaking on stage during her acceptance speech until the moment she finishes.\n\nThe resolution source will be the live video of the event.', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.11", "0.89"]', 'volume': '70977.25453', 'active': True, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-08-19T13:13:00.482638Z', 'updatedAt': '2024-08-23T01:10:16.576966Z', 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x2F5e3684cb1F318ec51b00Edba38d79Ac2c0aA9d', 'restricted': True, 'groupItemTitle': '<30 min', 'groupItemThreshold': '0', 'questionID': '0xeb5d197b786acdc43d91ceafcdc5eaf95ba47c85d16b26c77f7bdda904929200', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.01, 'orderMinSize': 5, 'volumeNum': 70977.25, 'liquidityNum': 6496.23, 'endDateIso': '2024-08-22', 'hasReviewedDates': True, 'volume24hr': 36324.16, 'clobTokenIds': '["110108178354982236137874653942215611185536295928259029459307043405440010439220", "36582545436626465858874182126222468544808602281042258429424829293320105800435"]', 'umaBond': '500', 'umaReward': '5', 'volume24hrClob': 36324.157567, 'volumeClob': 70977.25453, 'liquidityClob': 6496.2322, 'acceptingOrders': True, 'negRisk': True, 'negRiskMarketID': '0xeb5d197b786acdc43d91ceafcdc5eaf95ba47c85d16b26c77f7bdda904929200', 'negRiskRequestID': '0x3ab81c3b358de2a367d7100d45e9a0e58a7c5ac2ba91ea1c8d5645f2647a1ee5', 'commentCount': 24, '_sync': False, 'ready': False, 'funded': False, 'acceptingOrdersTimestamp': '2024-08-19T19:00:59Z', 'tags': [{'id': '100334', 'label': 'DNC', 'slug': 'dnc', 'forceShow': False, 'createdAt': '2024-08-08T17:23:09.325012Z', '_sync': False}, {'id': '2', 'label': 'Politics', 'slug': 'politics', 'forceShow': False, 'publishedAt': '2023-10-25 18:55:50.674+00', 'updatedBy': 13, 'createdAt': '2023-10-25T18:55:50.681Z', 'updatedAt': '2024-07-05T21:07:05.08170 ...
# {'id': '11797', 'ticker': 'will-kamala-drop-out-in-august', 'slug': 'will-kamala-drop-out-in-august', 'title': 'Will Kamala Harris drop out in August?', 'description': 'This market will resolve to "Yes" if Kamala Harris officially announces her withdrawal or is confirmed to have withdrawn from the 2024 US presidential race between August 1, 2024, 12:00 AM ET, and August 31, 2024, 11:59 PM ET. \n\nIn the event of any extenuating circumstances that prevent Kamala Harris from continuing the race, this market will also resolve to "Yes".\n\nIf Kamala Harris does not announce her withdrawal or is not forced to withdraw from the 2024 presidential race by the specified time, this market will resolve to "No".\n\nThe primary resolution source for this market will be official information from Kamala Harris or her official/legal representatives, however a consensus of credible reporting will also be used.\n\n', 'startDate': '2024-07-31T20:51:09.235182Z', 'creationDate': '2024-07-31T20:51:09.235178Z', 'endDate': '2024-08-31T12:00:00Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-kamala-drop-out-in-august-Kqu-PkCiyICz.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-kamala-drop-out-in-august-Kqu-PkCiyICz.jpg', 'active': True, 'closed': False, 'archived': False, 'new': False, 'featured': False, 'restricted': True, 'liquidity': 312825.55997, 'volume': 3283497.439875, 'createdAt': '2024-07-31T20:43:29.48298Z', 'updatedAt': '2024-08-23T01:09:11.792713Z', 'competitive': 0.8022384055993032, 'volume24hr': 143100.65, 'enableOrderBook': True, 'liquidityClob': 312825.55997, '_sync': False, 'commentCount': 17, 'markets': [{'id': '504399', 'question': 'Will Kamala Harris drop out in August?', 'conditionId': '0x05f242284d310c0face95345a008e80a530d41a706ccddf47167a7ebf6b76717', 'slug': 'will-kamala-drop-out-in-august', 'resolutionSource': '', 'endDate': '2024-08-31T12:00:00Z', 'liquidity': '312825.55997', 'startDate': '2024-08-07T14:03:18.889Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-kamala-drop-out-in-august-Kqu-PkCiyICz.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-kamala-drop-out-in-august-Kqu-PkCiyICz.jpg', 'description': 'This market will resolve to "Yes" if Kamala Harris officially announces her withdrawal or is confirmed to have withdrawn from the 2024 US presidential race between August 1, 2024, 12:00 AM ET, and August 31, 2024, 11:59 PM ET. \n\nIn the event of any extenuating circumstances that prevent Kamala Harris from continuing the race, this market will also resolve to "Yes".\n\nIf Kamala Harris does not announce her withdrawal or is not forced to withdraw from the 2024 presidential race by the specified time, this market will resolve to "No".\n\nThe primary resolution source for this market will be official information from Kamala Harris or her official/legal representatives, however a consensus of credible reporting will also be used.\n\n', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.0035", "0.9965"]', 'volume': '3283497.439875', 'active': True, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-07-31T20:43:31.317387Z', 'updatedAt': '2024-08-23T01:08:46.302492Z', 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74', 'restricted': True, 'groupItemTitle': '', 'groupItemThreshold': '0', 'questionID': '0xcf3ac9a885cb8afdae7f3e39d947a91ba69a73fbe261bb1348dc1807c25b7d7e', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.001, 'orderMinSize': 5, 'volumeNum': 3283497.44, 'liquidityNum': 312825.56, 'endDateIso': '2024-08-31', 'startDateIso': '2024-08-07', 'hasReviewedDates': True, 'volume24hr': 143100.65, 'clobTokenIds': '["102421387815191237331738744683995773684216429951408994781603999297405288616223", "30494108772513425001849192872617529159869609016840347957113911572325085864031"]', 'umaBond': '500', 'umaR ...

# %%
kamala_events['12088']['markets']
# Out:
# [{'id': '505244',
#   'question': 'Will Kamala Harris say "Couch" during DNC speech?',
#   'conditionId': '',
#   'slug': 'will-kamala-harris-say-couch-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '0',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "couch" during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word regardless of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count.\n\nCompound words will count as long as "couch" is part of the compound word and references the meaning which refers to a piece of furniture primarily used for sitting on.\n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'volume': '0',
#   'active': False,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-16T22:08:54.765715Z',
#   'updatedAt': '2024-08-21T19:35:36.957879Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '',
#   'archived': False,
#   'restricted': True,
#   'groupItemTitle': 'Couch',
#   'groupItemThreshold': '16',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 0,
#   'liquidityNum': 0,
#   'volume24hr': 0,
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrAmm': 0,
#   'volume24hrClob': 0,
#   'volumeAmm': 0,
#   'volumeClob': 0,
#   'liquidityAmm': 0,
#   'liquidityClob': 0,
#   'negRisk': False,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 1,
#   'oneDayPriceChange': 0,
#   'lastTradePrice': 0,
#   'bestBid': 0,
#   'bestAsk': 1},
#  {'id': '505245',
#   'question': 'Will Kamala Harris say "Coconut" during DNC speech?',
#   'conditionId': '',
#   'slug': 'will-kamala-harris-say-coconut-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '0',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "coconut" during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word regardless of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count.\n\nCompound words will count as long as "coconut" is part of the compound word and references the meaning which refers to a tropical fruit.\n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'volume': '0',
#   'active': False,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-16T22:09:44.85849Z',
#   'updatedAt': '2024-08-21T19:35:36.100505Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '',
#   'archived': False,
#   'restricted': True,
#   'groupItemTitle': 'Coconut',
#   'groupItemThreshold': '14',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 0,
#   'liquidityNum': 0,
#   'volume24hr': 0,
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrAmm': 0,
#   'volume24hrClob': 0,
#   'volumeAmm': 0,
#   'volumeClob': 0,
#   'liquidityAmm': 0,
#   'liquidityClob': 0,
#   'negRisk': False,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 1,
#   'oneDayPriceChange': 0,
#   'lastTradePrice': 0,
#   'bestBid': 0,
#   'bestAsk': 1},
#  {'id': '505246',
#   'question': 'Will Kamala Harris say "Context" during DNC speech?',
#   'conditionId': '0x7abb38afd204b7273867cab17477328312b0c97ad5ce741427b5c3e7e4f3f177',
#   'slug': 'will-kamala-harris-say-context-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '10194.9992',
#   'startDate': '2024-08-21T03:33:53.253Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "context" during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word regardless of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count.\n\nCompound words will count as long as "context" is part of the compound word and references the meaning which refers to the background information that gives meaning to a situation.\n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'outcomePrices': '["0.205", "0.795"]',
#   'volume': '45906.706044',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-16T22:13:57.636707Z',
#   'updatedAt': '2024-08-23T01:10:07.852482Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74',
#   'restricted': True,
#   'groupItemTitle': 'Context',
#   'groupItemThreshold': '10',
#   'questionID': '0xf9e3ea93e47944424a21f873c9aff4998366f5fbb84af4fbb9e5d75f527b501e',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 45906.71,
#   'liquidityNum': 10195,
#   'endDateIso': '2024-08-22',
#   'startDateIso': '2024-08-21',
#   'hasReviewedDates': True,
#   'volume24hr': 4335,
#   'clobTokenIds': '["64242673789653196900893525755093367003406704618571260581289556035477136357418", "40943039623605274813837075459861004235767554108398181280140053194586108160947"]',
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrClob': 4335.003472,
#   'volumeClob': 45906.706044,
#   'liquidityClob': 10194.9992,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'commentCount': 3,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2024-08-16T23:39:54Z',
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0.91994204365125,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'clobRewards': [{'id': '4646',
#     'conditionId': '0x7abb38afd204b7273867cab17477328312b0c97ad5ce741427b5c3e7e4f3f177',
#     'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#     'rewardsAmount': 0,
#     'rewardsDailyRate': 30,
#     'startDate': '2024-08-16',
#     'endDate': '2500-12-31'}],
#   'rewardsMinSize': 20,
#   'rewardsMaxSpread': 3.5,
#   'spread': 0.03,
#   'oneDayPriceChange': -0.105,
#   'lastTradePrice': 0.22,
#   'bestBid': 0.19,
#   'bestAsk': 0.22,
#   'automaticallyActive': True},
#  {'id': '505247',
#   'question': 'Will Kamala Harris say "Weird" or "Weirdo" during DNC speech?',
#   'conditionId': '0x6fa74db3be25f8d3ab9064d75e58c30dbd96609a18b301bc128b63a590e9fb83',
#   'slug': 'will-kamala-harris-say-weird-or-weirdo-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '10685.8769',
#   'startDate': '2024-08-16T23:39:41.585Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "weird "or "weirdo" during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word regardless of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count.\n\nCompound words will count as long as "weird "or "weirdo" is part of the compound word and references the meaning which refers to a person who behaves unusually or oddly.\n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'outcomePrices': '["0.285", "0.715"]',
#   'volume': '175641.9173',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-16T22:15:14.319032Z',
#   'updatedAt': '2024-08-23T01:08:51.170212Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74',
#   'restricted': True,
#   'groupItemTitle': 'Weird/Weirdo',
#   'groupItemThreshold': '1',
#   'questionID': '0x1891f589b348f470366a1823f9dd3fadf5b777201e6d9735b26ec9a1811bd632',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 175641.92,
#   'liquidityNum': 10685.88,
#   'endDateIso': '2024-08-22',
#   'startDateIso': '2024-08-16',
#   'hasReviewedDates': True,
#   'volume24hr': 34255.77,
#   'clobTokenIds': '["80680245878409911467909913755812666810346476055281703288123812261305904086837", "61792787549897504942562730797101887148739013606647117732489355366499995533562"]',
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrClob': 34255.769961,
#   'volumeClob': 175641.9173,
#   'liquidityClob': 10685.8769,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'commentCount': 75,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2024-08-16T23:37:02Z',
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0.9558173433056943,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'clobRewards': [{'id': '4639',
#     'conditionId': '0x6fa74db3be25f8d3ab9064d75e58c30dbd96609a18b301bc128b63a590e9fb83',
#     'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#     'rewardsAmount': 0,
#     'rewardsDailyRate': 30,
#     'startDate': '2024-08-16',
#     'endDate': '2500-12-31'}],
#   'rewardsMinSize': 20,
#   'rewardsMaxSpread': 3.5,
#   'spread': 0.01,
#   'oneDayPriceChange': -0.04,
#   'lastTradePrice': 0.29,
#   'bestBid': 0.28,
#   'bestAsk': 0.29,
#   'automaticallyActive': True},
#  {'id': '505248',
#   'question': 'Will Kamala Harris say "Crypto" or "Bitcoin" during DNC speech?',
#   'conditionId': '0xf00ac5f251f3ceaeb95f53d4c579c31233738626ffa09033ede3e86e8291f10e',
#   'slug': 'will-kamala-harris-say-crypto-or-bitcoin-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '13765.38254',
#   'startDate': '2024-08-22T21:16:55.209Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "crypto" or "Bitcoin" during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word  regardless of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count.\n\nCompound words will count as long as "crypto" or "Bitcoin" is part of the compound word and references the meaning which refers to decentralized cryptocurrency (e.g. "cryptocurrency-related" counts).\n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'outcomePrices': '["0.0605", "0.9395"]',
#   'volume': '50606.492573',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-16T22:26:42.70573Z',
#   'updatedAt': '2024-08-23T01:10:26.132815Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74',
#   'restricted': True,
#   'groupItemTitle': 'Crypto/Bitcoin',
#   'groupItemThreshold': '11',
#   'questionID': '0x3733b5b74133e968760b895b77d1673f1e037a724df7b44ef6f22c350484c7a4',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.001,
#   'orderMinSize': 5,
#   'volumeNum': 50606.49,
#   'liquidityNum': 13765.38,
#   'endDateIso': '2024-08-22',
#   'startDateIso': '2024-08-22',
#   'hasReviewedDates': True,
#   'volume24hr': 49737.41,
#   'clobTokenIds': '["52621283377354023691113953450971868493788002537708322363354446334977147532660", "39408446622885665959107920337927924836729385315201224303125445265084389661118"]',
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrClob': 49737.413995,
#   'volumeClob': 50606.492573,
#   'liquidityClob': 13765.38254,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'commentCount': 0,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2024-08-21T21:31:21Z',
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0.8381103879382505,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'clobRewards': [{'id': '4897',
#     'conditionId': '0xf00ac5f251f3ceaeb95f53d4c579c31233738626ffa09033ede3e86e8291f10e',
#     'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#     'rewardsAmount': 0,
#     'rewardsDailyRate': 50,
#     'startDate': '2024-08-21',
#     'endDate': '2500-12-31'}],
#   'rewardsMinSize': 20,
#   'rewardsMaxSpread': 3.5,
#   'spread': 0.055,
#   'oneDayPriceChange': 0.0005,
#   'lastTradePrice': 0.069,
#   'bestBid': 0.033,
#   'bestAsk': 0.088,
#   'automaticallyActive': True},
#  {'id': '505249',
#   'question': 'Will Kamala Harris say "abortion" during DNC speech?',
#   'conditionId': '0x5b6387e2281693a19785e12e8859d992533c257bcc34aa33ac8856f71b0d8769',
#   'slug': 'will-kamala-harris-say-abortion-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '12304.1706',
#   'startDate': '2024-08-21T15:38:12.192Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "abortion" during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word regardless of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count.\n\nCompound words will count as long as "Abortion" is part of the compound word and references the meaning which refers to the termination of a pregnancy.\n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'outcomePrices': '["0.84", "0.16"]',
#   'volume': '272951.254914',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-16T22:27:47.491302Z',
#   'updatedAt': '2024-08-23T01:08:50.509722Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74',
#   'restricted': True,
#   'groupItemTitle': 'Abortion',
#   'groupItemThreshold': '2',
#   'questionID': '0x4fea0f09ed30ad5db46869d9a2f6e7e56e8a49e10be3a9b3f42c4c7b53356297',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 272951.25,
#   'liquidityNum': 12304.17,
#   'endDateIso': '2024-08-22',
#   'startDateIso': '2024-08-21',
#   'hasReviewedDates': True,
#   'volume24hr': 70424.9,
#   'clobTokenIds': '["93486332194041876442047340588416458858761871687634872878981632587794405543234", "101821310452091566976263744002699226214287094464857959534436342668725034505377"]',
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrClob': 70424.898999,
#   'volumeClob': 272951.254914,
#   'liquidityClob': 12304.1706,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'commentCount': 33,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2024-08-16T23:38:48Z',
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0.8963786303334529,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'clobRewards': [{'id': '4640',
#     'conditionId': '0x5b6387e2281693a19785e12e8859d992533c257bcc34aa33ac8856f71b0d8769',
#     'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#     'rewardsAmount': 0,
#     'rewardsDailyRate': 30,
#     'startDate': '2024-08-16',
#     'endDate': '2500-12-31'}],
#   'rewardsMinSize': 20,
#   'rewardsMaxSpread': 3.5,
#   'spread': 0.02,
#   'oneDayPriceChange': 0.045,
#   'lastTradePrice': 0.83,
#   'bestBid': 0.83,
#   'bestAsk': 0.85,
#   'automaticallyActive': True},
#  {'id': '505250',
#   'question': 'Will Kamala Harris say "Ukraine" during DNC speech?',
#   'conditionId': '0x2a966d9dbee1f52aa1fff9005a6f1a0c19887e34a4ff6c90e2013d5725f89294',
#   'slug': 'will-kamala-harris-say-ukraine-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '7963.0508',
#   'startDate': '2024-08-21T15:38:15.852Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "Ukraine" during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word  regardless of context of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count.\n\nCompound words will count as long as "Ukraine" is part of the compound word and references the meaning which refers to the Eastern European country.\n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'outcomePrices': '["0.3", "0.7"]',
#   'volume': '17653.907943',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-16T22:43:43.047133Z',
#   'updatedAt': '2024-08-23T01:10:05.330368Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74',
#   'restricted': True,
#   'groupItemTitle': 'Ukraine',
#   'groupItemThreshold': '15',
#   'questionID': '0xfd0a29d93754963362a8849ec54a77f2d96a6686ab05124ba7342b58cb8f1bad',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 17653.91,
#   'liquidityNum': 7963.05,
#   'endDateIso': '2024-08-22',
#   'startDateIso': '2024-08-21',
#   'hasReviewedDates': True,
#   'volume24hr': 14885.91,
#   'clobTokenIds': '["26593447764292832285314112216072340621740177231383377377022909167020983270520", "1285796292421504659293607230282695544863738688590861869096995860929467839190"]',
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrClob': 14885.910431,
#   'volumeClob': 17653.907943,
#   'liquidityClob': 7963.0508,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'commentCount': 2,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2024-08-21T03:46:08Z',
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0.9615384615384615,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'clobRewards': [{'id': '4794',
#     'conditionId': '0x2a966d9dbee1f52aa1fff9005a6f1a0c19887e34a4ff6c90e2013d5725f89294',
#     'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#     'rewardsAmount': 0,
#     'rewardsDailyRate': 20,
#     'startDate': '2024-08-21',
#     'endDate': '2500-12-31'}],
#   'rewardsMinSize': 20,
#   'rewardsMaxSpread': 3.5,
#   'spread': 0.06,
#   'oneDayPriceChange': -0.05,
#   'lastTradePrice': 0.36,
#   'bestBid': 0.27,
#   'bestAsk': 0.33,
#   'automaticallyActive': True},
#  {'id': '505251',
#   'question': 'Will Kamala Harris say "China" during DNC speech?',
#   'conditionId': '',
#   'slug': 'will-kamala-harris-say-china-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '0',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "China" during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word  regardless of context of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count.\n\nCompound words will count as long as "Ukraine" is part of the compound word and references the meaning which refers to the East Asian country.\n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'volume': '0',
#   'active': False,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-16T22:46:40.258969Z',
#   'updatedAt': '2024-08-21T19:35:37.391504Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '',
#   'archived': False,
#   'restricted': True,
#   'groupItemTitle': 'China',
#   'groupItemThreshold': '17',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 0,
#   'liquidityNum': 0,
#   'volume24hr': 0,
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrAmm': 0,
#   'volume24hrClob': 0,
#   'volumeAmm': 0,
#   'volumeClob': 0,
#   'liquidityAmm': 0,
#   'liquidityClob': 0,
#   'negRisk': False,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 1,
#   'oneDayPriceChange': 0,
#   'lastTradePrice': 0,
#   'bestBid': 0,
#   'bestAsk': 1},
#  {'id': '505255',
#   'question': 'Will Kamala Harris say "Venn diagram" during DNC speech?',
#   'conditionId': '',
#   'slug': 'will-kamala-harris-say-venn-diagram-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '0',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "Venn diagram" during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the phrase regardless of context of context will count toward the resolution of this market.\n\nPluralization/possessive of the phrase will count toward the resolution of this market, however other forms will NOT count.\n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'volume': '0',
#   'active': False,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-16T22:53:50.975375Z',
#   'updatedAt': '2024-08-21T19:35:15.884367Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '',
#   'archived': False,
#   'restricted': True,
#   'groupItemTitle': 'Venn diagram',
#   'groupItemThreshold': '18',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 0,
#   'liquidityNum': 0,
#   'volume24hr': 0,
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrAmm': 0,
#   'volume24hrClob': 0,
#   'volumeAmm': 0,
#   'volumeClob': 0,
#   'liquidityAmm': 0,
#   'liquidityClob': 0,
#   'negRisk': False,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 1,
#   'oneDayPriceChange': 0,
#   'lastTradePrice': 0,
#   'bestBid': 0,
#   'bestAsk': 1},
#  {'id': '505252',
#   'question': 'Will Kamala Harris say "Palestine" during DNC speech?',
#   'conditionId': '',
#   'slug': 'will-kamala-harris-say-palestine-during-dnc-speech-apom',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '0',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "Palestine" during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word  regardless of context of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count (i.e. "Palestinian" would not count).\n\nCompound words will count as long as "Palestine" is part of the compound word and references the meaning which refers to a territory in the Middle East.\n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'volume': '0',
#   'active': False,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-16T22:48:57.794833Z',
#   'updatedAt': '2024-08-22T21:16:55.90707Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '',
#   'archived': False,
#   'restricted': True,
#   'groupItemTitle': 'Palestine',
#   'groupItemThreshold': '12',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 0,
#   'liquidityNum': 0,
#   'volume24hr': 0,
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrAmm': 0,
#   'volume24hrClob': 0,
#   'volumeAmm': 0,
#   'volumeClob': 0,
#   'liquidityAmm': 0,
#   'liquidityClob': 0,
#   'negRisk': False,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 1,
#   'oneDayPriceChange': 0,
#   'lastTradePrice': 0,
#   'bestBid': 0,
#   'bestAsk': 1},
#  {'id': '505253',
#   'question': 'Will Kamala Harris say "Jew" during DNC speech?',
#   'conditionId': '0x1ff061748325e27c09cb2f227bf5c830efc332ba61431d437ac869627e030862',
#   'slug': 'will-kamala-harris-say-jew-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '15698.8158',
#   'startDate': '2024-08-16T23:40:01.609Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "Jew" during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word regardless of context of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count (i.e. "Jewish" would not count").\n\nCompound words will count as long as "Jew" is part of the compound word and references the meaning which refers to a person who practices Judaism. \n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'outcomePrices': '["0.105", "0.895"]',
#   'volume': '138750.853097',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-16T22:51:24.003915Z',
#   'updatedAt': '2024-08-23T01:10:11.980464Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74',
#   'restricted': True,
#   'groupItemTitle': 'Jew',
#   'groupItemThreshold': '8',
#   'questionID': '0x46c703b52620cea6f3a0b8a1f13b995afcce15fadb39175827d1035b2f5552de',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 138750.85,
#   'liquidityNum': 15698.82,
#   'endDateIso': '2024-08-22',
#   'startDateIso': '2024-08-16',
#   'hasReviewedDates': True,
#   'volume24hr': 58061.88,
#   'clobTokenIds': '["16551027993616244750753488400732231009784672775561860263092495293302311736274", "41653647934294544153567298055576686810974504823784945654445131642158690046275"]',
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrClob': 58061.883949,
#   'volumeClob': 138750.853097,
#   'liquidityClob': 15698.8158,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'commentCount': 26,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2024-08-16T23:35:54Z',
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0.865033195648883,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'clobRewards': [{'id': '4641',
#     'conditionId': '0x1ff061748325e27c09cb2f227bf5c830efc332ba61431d437ac869627e030862',
#     'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#     'rewardsAmount': 0,
#     'rewardsDailyRate': 30,
#     'startDate': '2024-08-16',
#     'endDate': '2500-12-31'}],
#   'rewardsMinSize': 20,
#   'rewardsMaxSpread': 3.5,
#   'spread': 0.01,
#   'oneDayPriceChange': 0.055,
#   'lastTradePrice': 0.11,
#   'bestBid': 0.1,
#   'bestAsk': 0.11,
#   'automaticallyActive': True},
#  {'id': '505578',
#   'question': 'Will Kamala Harris say "Inflation" during DNC speech?',
#   'conditionId': '0x624fc04e8309aa163af6859aaa516c6d65759270f97ac1c92374ae9900649b38',
#   'slug': 'will-kamala-harris-say-inflation-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '5378.6955',
#   'startDate': '2024-08-22T21:14:29.664Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "inflation" during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word regardless of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count.\n\nCompound words will count as long as "inflation" is part of the compound word and references the meaning which refers to increases in costs of goods and services.\n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'outcomePrices': '["0.685", "0.315"]',
#   'volume': '15091.518454',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-21T19:34:56.869803Z',
#   'updatedAt': '2024-08-23T01:10:17.547944Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74',
#   'restricted': True,
#   'groupItemTitle': 'Inflation',
#   'groupItemThreshold': '4',
#   'questionID': '0xb8b1087e581cf053082ea8776bb9f7138f0bcfc6ae3cafd3b809f5553aae254c',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 15091.52,
#   'liquidityNum': 5378.7,
#   'endDateIso': '2024-08-22',
#   'startDateIso': '2024-08-22',
#   'hasReviewedDates': True,
#   'volume24hr': 14602.11,
#   'clobTokenIds': '["111265313473835260288817186956223149768346877953934247741160316324523147345931", "14850542044047492793462143617574206664705451184414680385098796368674208527255"]',
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrClob': 14602.111538,
#   'volumeClob': 15091.518454,
#   'liquidityClob': 5378.6955,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'commentCount': 11,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2024-08-21T19:37:53Z',
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0.9669075878072954,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'clobRewards': [{'id': '4894',
#     'conditionId': '0x624fc04e8309aa163af6859aaa516c6d65759270f97ac1c92374ae9900649b38',
#     'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#     'rewardsAmount': 0,
#     'rewardsDailyRate': 70,
#     'startDate': '2024-08-21',
#     'endDate': '2500-12-31'}],
#   'rewardsMinSize': 20,
#   'rewardsMaxSpread': 4.5,
#   'spread': 0.03,
#   'oneDayPriceChange': -0.19,
#   'lastTradePrice': 0.67,
#   'bestBid': 0.67,
#   'bestAsk': 0.7,
#   'automaticallyActive': True},
#  {'id': '505254',
#   'question': 'Will Kamala Harris say "Unburdened" during DNC speech?',
#   'conditionId': '0x1a4f04c2e6c000d9fc524eb12e7333217411a226c34745af140f195c0227cd5f',
#   'slug': 'will-kamala-harris-say-unburdened-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '9734.3561',
#   'startDate': '2024-08-16T23:39:42.989Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
# ...
#   'competitive': 0.9993753903810119,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'clobRewards': [{'id': '4644',
#     'conditionId': '0x4613844d9d74779bfc714a9d8b6e03a81b8a54d2a45adc0bdb4b34f49427050d',
#     'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#     'rewardsAmount': 0,
#     'rewardsDailyRate': 30,
#     'startDate': '2024-08-16',
#     'endDate': '2500-12-31'}],
#   'rewardsMinSize': 20,
#   'rewardsMaxSpread': 3.5,
#   'spread': 0.01,
#   'oneDayPriceChange': -0.04,
#   'lastTradePrice': 0.48,
#   'bestBid': 0.47,
#   'bestAsk': 0.48,
#   'automaticallyActive': True},
#  {'id': '505560',
#   'question': 'Will Kamala Harris say "America" 5 or more times during DNC speech?',
#   'conditionId': '',
#   'slug': 'will-kamala-harris-say-america-5-or-more-times-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '0',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "America" 5 or more times during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word regardless of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count.\n\nCompound words will count as long as "America" is part of the compound word and references the meaning which refers to the United States of America.\n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'volume': '0',
#   'active': False,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-21T16:21:59.908167Z',
#   'updatedAt': '2024-08-21T19:35:04.741187Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '',
#   'archived': False,
#   'restricted': True,
#   'groupItemTitle': 'America 5+ times',
#   'groupItemThreshold': '27',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 0,
#   'liquidityNum': 0,
#   'volume24hr': 0,
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrAmm': 0,
#   'volume24hrClob': 0,
#   'volumeAmm': 0,
#   'volumeClob': 0,
#   'liquidityAmm': 0,
#   'liquidityClob': 0,
#   'negRisk': False,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 1,
#   'oneDayPriceChange': 0,
#   'lastTradePrice': 0,
#   'bestBid': 0,
#   'bestAsk': 1},
#  {'id': '505561',
#   'question': 'Will Kamala Harris say "Woman" 3 or more times during DNC speech?',
#   'conditionId': '',
#   'slug': 'will-kamala-harris-say-woman-3-or-more-times-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '0',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "woman" 3 or more times during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word regardless of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count.\n\nCompound words will count as long as "woman" is part of the compound word and references the meaning which refers to a person belonging to the feminine gender.\n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'volume': '0',
#   'active': False,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-21T16:24:01.231688Z',
#   'updatedAt': '2024-08-21T19:35:05.231544Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '',
#   'archived': False,
#   'restricted': True,
#   'groupItemTitle': 'Woman 3+ times',
#   'groupItemThreshold': '28',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 0,
#   'liquidityNum': 0,
#   'volume24hr': 0,
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrAmm': 0,
#   'volume24hrClob': 0,
#   'volumeAmm': 0,
#   'volumeClob': 0,
#   'liquidityAmm': 0,
#   'liquidityClob': 0,
#   'negRisk': False,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 1,
#   'oneDayPriceChange': 0,
#   'lastTradePrice': 0,
#   'bestBid': 0,
#   'bestAsk': 1},
#  {'id': '505444',
#   'question': 'Will Kamala Harris say "Donald" or "Trump" 5 or more times during DNC speech?',
#   'conditionId': '0x1c8a4a4de38ae64f120b079474eca7ebfc2cd0e641e30a26bfe1963223fc646e',
#   'slug': 'will-kamala-harris-say-donald-or-trump-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '12594.6656',
#   'startDate': '2024-08-20T19:42:24.019Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "Donald" or "Trump" 5 or more times during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word regardless of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count.\n\nCompound words will count as long as "Donald" or "Trump" is part of the compound word and references the meaning which refers to the person Donald Trump. \n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'outcomePrices': '["0.86", "0.14"]',
#   'volume': '91128.495042',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-20T19:35:57.131599Z',
#   'updatedAt': '2024-08-23T01:08:39.301878Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74',
#   'restricted': True,
#   'groupItemTitle': 'Donald Trump 5+ times',
#   'groupItemThreshold': '7',
#   'questionID': '0xc27f4e51cad4ac6a0ad90b9513b89a1d0c91d251e5ff7f44ccb2bf3ee1693d6a',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 91128.5,
#   'liquidityNum': 12594.67,
#   'endDateIso': '2024-08-22',
#   'startDateIso': '2024-08-20',
#   'hasReviewedDates': True,
#   'volume24hr': 68662.94,
#   'clobTokenIds': '["112691550711713354714525509796202337193505769808087674259394206524293080902258", "40934908860656143479579576067633881276941830984503767038689094076378988206631"]',
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrClob': 68662.944252,
#   'volumeClob': 91128.495042,
#   'liquidityClob': 12594.6656,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'commentCount': 20,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2024-08-20T19:38:47Z',
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0.8852691218130312,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'clobRewards': [{'id': '4766',
#     'conditionId': '0x1c8a4a4de38ae64f120b079474eca7ebfc2cd0e641e30a26bfe1963223fc646e',
#     'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#     'rewardsAmount': 0,
#     'rewardsDailyRate': 60,
#     'startDate': '2024-08-20',
#     'endDate': '2500-12-31'}],
#   'rewardsMinSize': 20,
#   'rewardsMaxSpread': 3.5,
#   'spread': 0.02,
#   'oneDayPriceChange': 0.015,
#   'lastTradePrice': 0.87,
#   'bestBid': 0.85,
#   'bestAsk': 0.87,
#   'automaticallyActive': True},
#  {'id': '505243',
#   'question': 'Will Kamala Harris say "Inflation" 3 or more times during DNC speech?',
#   'conditionId': '0x89bac5804383f9df93e5dc7e14fa065ae7d527eaf9c856170eab79e30f317bc4',
#   'slug': 'will-kamala-harris-say-inflation-3-or-more-times-during-dnc-speech',
#   'resolutionSource': '',
#   'endDate': '2024-08-22T12:00:00Z',
#   'liquidity': '10696.6816',
#   'startDate': '2024-08-16T23:39:41.263Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-will-kamala-say-during-acceptance-speech-leRt-BQhn2yG.jpg',
#   'description': 'This market will resolve to "Yes" if Kamala Harris says "inflation" 3 or more times during her DNC keynote speech. Otherwise, the market will resolve to "No".\n\nIf Kamala Harris does not give a keynote speech at the DNC this market will resolve to "No".\n\nAny usage of the word regardless of context will count toward the resolution of this market.\n\nPluralization/possessive of the word will count toward the resolution of this market, however other forms will NOT count.\n\nCompound words will count as long as "inflation" is part of the compound word and references the meaning which refers to increases in costs of goods and services.\n\nThe resolution source will be the video of the speech.',
#   'outcomes': '["Yes", "No"]',
#   'outcomePrices': '["0.13", "0.87"]',
#   'volume': '170870.59881',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2024-08-16T22:07:50.237672Z',
#   'updatedAt': '2024-08-23T01:08:51.544514Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74',
#   'restricted': True,
#   'groupItemTitle': 'Inflation 3+ times',
#   'groupItemThreshold': '5',
#   'questionID': '0x9c96de9f765229742a517a7acee8fa5bd1e69cf9fee22829bb6fcc1f6c224043',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 170870.6,
#   'liquidityNum': 10696.68,
#   'endDateIso': '2024-08-22',
#   'startDateIso': '2024-08-16',
#   'hasReviewedDates': True,
#   'volume24hr': 48984.28,
#   'clobTokenIds': '["29477624677732662130755250411641498121808388442935173353177514611687054500990", "109242723591257492717998717073698103421339472347171521634857245555008275898469"]',
#   'umaBond': '500',
#   'umaReward': '5',
#   'volume24hrClob': 48984.277946,
#   'volumeClob': 170870.59881,
#   'liquidityClob': 10696.6816,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'commentCount': 18,
#   '_sync': False,
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2024-08-16T23:36:14Z',
#   'tags': [{'id': '24',
#     'label': 'US Election',
#     'slug': 'us-election',
#     'forceShow': True,
#     'publishedAt': '2023-11-02 21:04:03.712+00',
#     'updatedBy': 15,
#     'createdAt': '2023-11-02T21:04:03.723Z',
#     'updatedAt': '2024-05-01T17:30:24.691205Z',
#     '_sync': False},
#    {'id': '2',
#     'label': 'Politics',
#     'slug': 'politics',
#     'forceShow': False,
#     'publishedAt': '2023-10-25 18:55:50.674+00',
#     'updatedBy': 13,
#     'createdAt': '2023-10-25T18:55:50.681Z',
#     'updatedAt': '2024-07-05T21:07:05.081707Z',
#     '_sync': False,
#     'forceHide': True},
#    {'id': '100334',
#     'label': 'DNC',
#     'slug': 'dnc',
#     'forceShow': False,
#     'createdAt': '2024-08-08T17:23:09.325012Z',
#     '_sync': False},
#    {'id': '100291',
#     'label': 'Kamala',
#     'slug': 'kamala',
#     'createdAt': '2024-07-03T16:53:53.477357Z',
#     '_sync': False},
#    {'id': '100343',
#     'label': 'Mention Markets',
#     'slug': 'mention-markets',
#     'forceShow': False,
#     'createdAt': '2024-08-16T02:29:11.548984Z',
#     '_sync': False}],
#   'cyom': False,
#   'competitive': 0.8795848359574281,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'clobRewards': [{'id': '4638',
#     'conditionId': '0x89bac5804383f9df93e5dc7e14fa065ae7d527eaf9c856170eab79e30f317bc4',
#     'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#     'rewardsAmount': 0,
#     'rewardsDailyRate': 60,
#     'startDate': '2024-08-16',
#     'endDate': '2500-12-31'}],
#   'rewardsMinSize': 20,
#   'rewardsMaxSpread': 3.5,
#   'spread': 0.02,
#   'oneDayPriceChange': -0.005,
#   'lastTradePrice': 0.12,
#   'bestBid': 0.12,
#   'bestAsk': 0.14,
#   'automaticallyActive': True}]

# %%
for market in kamala_events['12088']['markets']:
  if 'outcomePrices' in market and 'clobTokenIds' in market:
    print(market['id'], market['question'], 'outcomePrices' in market and market['outcomePrices'])
    print('clobTokenIds' in market and market['clobTokenIds'])
    print('=====')
# Out:
# 505246 Will Kamala Harris say "Context" during DNC speech? ["0.205", "0.795"]
# ["64242673789653196900893525755093367003406704618571260581289556035477136357418", "40943039623605274813837075459861004235767554108398181280140053194586108160947"]
# =====
# 505247 Will Kamala Harris say "Weird" or "Weirdo" during DNC speech? ["0.285", "0.715"]
# ["80680245878409911467909913755812666810346476055281703288123812261305904086837", "61792787549897504942562730797101887148739013606647117732489355366499995533562"]
# =====
# 505248 Will Kamala Harris say "Crypto" or "Bitcoin" during DNC speech? ["0.0605", "0.9395"]
# ["52621283377354023691113953450971868493788002537708322363354446334977147532660", "39408446622885665959107920337927924836729385315201224303125445265084389661118"]
# =====
# 505249 Will Kamala Harris say "abortion" during DNC speech? ["0.84", "0.16"]
# ["93486332194041876442047340588416458858761871687634872878981632587794405543234", "101821310452091566976263744002699226214287094464857959534436342668725034505377"]
# =====
# 505250 Will Kamala Harris say "Ukraine" during DNC speech? ["0.3", "0.7"]
# ["26593447764292832285314112216072340621740177231383377377022909167020983270520", "1285796292421504659293607230282695544863738688590861869096995860929467839190"]
# =====
# 505253 Will Kamala Harris say "Jew" during DNC speech? ["0.105", "0.895"]
# ["16551027993616244750753488400732231009784672775561860263092495293302311736274", "41653647934294544153567298055576686810974504823784945654445131642158690046275"]
# =====
# 505578 Will Kamala Harris say "Inflation" during DNC speech? ["0.685", "0.315"]
# ["111265313473835260288817186956223149768346877953934247741160316324523147345931", "14850542044047492793462143617574206664705451184414680385098796368674208527255"]
# =====
# 505254 Will Kamala Harris say "Unburdened" during DNC speech? ["0.175", "0.825"]
# ["23360939988679364027624185518382759743328544433592111535569478055890815567848", "90873340590389265013640328846784957569240682582615829106027433526304233168008"]
# =====
# 505257 Will Kamala Harris say "Project 2025" during DNC speech? ["0.9355", "0.0645"]
# ["96559938682276034645806141299746584878954217392802290647610066974896915513103", "47632859451812925607024824367112114788907243768362133480186079235034677166362"]
# =====
# 505258 Will Kamala Harris say "Not going back" during DNC speech? ["0.948", "0.052"]
# ["72113244188350953717898632223467968939807729155081708390484471834948439049662", "90530275633730921481181538706970740910254477559876471624923370473833650122918"]
# =====
# 505260 Will Kamala Harris say "Obama" during DNC speech? ["0.325", "0.675"]
# ["53340103183404656827493394042456164703360575431367840018315900186928552315110", "11713312711101975538078573275702847134257174377278903397978050737128797615928"]
# =====
# 505261 Will Kamala Harris say "McDonald's" during DNC speech? ["0.655", "0.345"]
# ["96570979380048353785486044478679406331360143193656194178338866611003846474481", "6191526631599711031002149251255941518870242710164750030493892128696051820273"]
# =====
# 505263 Will Kamala Harris say "Joy" during DNC speech? ["0.61", "0.39"]
# ["13326891895659731216780625212309049525490250308198050970062259484725251626980", "85966196746081128399342715621719739866019638916469350017797754178188334059060"]
# =====
# 505558 Will Kamala Harris say "Oakland" during DNC speech? ["0.805", "0.195"]
# ["39998470967620059068588653605949914689985457855821389254718377791316973940157", "72959750195426776044860813418400399280993755202129252269451764925642423268484"]
# =====
# 505264 Will Kamala Harris say "Monkeypox" during DNC speech? ["0.034", "0.966"]
# ["111502923747929334760697428158248035741750303289705077233684024824063752359646", "50413696888756267681220082003131147683796905866758853877144868606910124194797"]
# =====
# 505559 Will Kamala Harris say "Antisemitism" during DNC speech? ["0.155", "0.845"]
# ["113095838904792670538676379265042503535399251421246242903883088801902098241124", "112237150948395488604021832543779990167012759526832186868774690815086409681337"]
# =====
# 505265 Will Kamala Harris say "Ceasefire" during DNC speech? ["0.475", "0.525"]
# ["7440762364213373256562615921080334008579133772098814514780020356482019026713", "51423471552746684084729243163649445804136954683723754770004797460872697665852"]
# =====
# 505444 Will Kamala Harris say "Donald" or "Trump" 5 or more times during DNC speech? ["0.86", "0.14"]
# ["112691550711713354714525509796202337193505769808087674259394206524293080902258", "40934908860656143479579576067633881276941830984503767038689094076378988206631"]
# =====
# 505243 Will Kamala Harris say "Inflation" 3 or more times during DNC speech? ["0.13", "0.87"]
# ["29477624677732662130755250411641498121808388442935173353177514611687054500990", "109242723591257492717998717073698103421339472347171521634857245555008275898469"]
# =====

# %% [markdown]
# # Streaming Data

# %%
# !pip install websockets -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.2/157.2 kB 7.7 MB/s eta 0:00:00

# %%
import json
import asyncio
import websockets
import datetime
url = 'wss://ws-subscriptions-clob.polymarket.com/ws/market'
last_time_pong = datetime.datetime.now()
msgs = []

kamala_trump_yes_token = "112691550711713354714525509796202337193505769808087674259394206524293080902258"
kamala_trump_no_token = "40934908860656143479579576067633881276941830984503767038689094076378988206631"

trump_win_election_yes = "21742633143463906290569050155826241533067272736897614950488156847949938836455"
trump_win_election_no = "48331043336612883890938759509493159234755048973500640148014422747788308965732"

async with websockets.connect(url) as websocket:
    await websocket.send(json.dumps({"assets_ids":[kamala_trump_yes_token, kamala_trump_no_token],"type":"market"}))

    while True:
        m = await websocket.recv()
        if m != "PONG":
          last_time_pong = datetime.datetime.now()
        d = json.loads(m)
        print(d)
        if last_time_pong + datetime.timedelta(seconds=10) < datetime.datetime.now():
          await websocket.send("PING")
        else:
            msgs.append(d)
# Out:
# {'asks': [{'price': '0.99', 'size': '60147.9'}, {'price': '0.98', 'size': '2422'}, {'price': '0.97', 'size': '1500'}, {'price': '0.96', 'size': '1087.67'}, {'price': '0.95', 'size': '60'}, {'price': '0.91', 'size': '955'}, {'price': '0.9', 'size': '13.88'}, {'price': '0.88', 'size': '1749.2'}, {'price': '0.87', 'size': '2119.25'}], 'asset_id': '112691550711713354714525509796202337193505769808087674259394206524293080902258', 'bids': [{'price': '0.01', 'size': '60020'}, {'price': '0.03', 'size': '50'}, {'price': '0.04', 'size': '2500'}, {'price': '0.2', 'size': '75'}, {'price': '0.21', 'size': '952'}, {'price': '0.31', 'size': '52.98'}, {'price': '0.4', 'size': '200'}, {'price': '0.5', 'size': '200'}, {'price': '0.51', 'size': '1227.8'}, {'price': '0.6', 'size': '200'}, {'price': '0.65', 'size': '434.17'}, {'price': '0.7', 'size': '100'}, {'price': '0.75', 'size': '533.69'}, {'price': '0.77', 'size': '10'}, {'price': '0.79', 'size': '750'}, {'price': '0.82', 'size': '22'}, {'price': '0.83', 'size': '266.3'}, {'price': '0.85', 'size': '9137.08'}], 'event_type': 'book', 'hash': 'b4e5c72c81f274f7e715cd81cc910ae10d216017', 'market': '0x1c8a4a4de38ae64f120b079474eca7ebfc2cd0e641e30a26bfe1963223fc646e'}
# {'asks': [{'price': '0.99', 'size': '60020'}, {'price': '0.97', 'size': '50'}, {'price': '0.96', 'size': '2500'}, {'price': '0.8', 'size': '75'}, {'price': '0.79', 'size': '952'}, {'price': '0.69', 'size': '52.98'}, {'price': '0.6', 'size': '200'}, {'price': '0.5', 'size': '200'}, {'price': '0.49', 'size': '1227.8'}, {'price': '0.4', 'size': '200'}, {'price': '0.35', 'size': '434.17'}, {'price': '0.3', 'size': '100'}, {'price': '0.25', 'size': '533.69'}, {'price': '0.23', 'size': '10'}, {'price': '0.21', 'size': '750'}, {'price': '0.18', 'size': '22'}, {'price': '0.17', 'size': '266.3'}, {'price': '0.15', 'size': '9137.08'}], 'asset_id': '40934908860656143479579576067633881276941830984503767038689094076378988206631', 'bids': [{'price': '0.01', 'size': '60147.9'}, {'price': '0.02', 'size': '2422'}, {'price': '0.03', 'size': '1500'}, {'price': '0.04', 'size': '1087.67'}, {'price': '0.05', 'size': '60'}, {'price': '0.09', 'size': '955'}, {'price': '0.1', 'size': '13.88'}, {'price': '0.12', 'size': '1749.2'}, {'price': '0.13', 'size': '2119.25'}], 'event_type': 'book', 'hash': 'd19b2a1a4fff8f0a29fbf8fc940f62ec532bf0e3', 'market': '0x1c8a4a4de38ae64f120b079474eca7ebfc2cd0e641e30a26bfe1963223fc646e'}
# {'asset_id': '40934908860656143479579576067633881276941830984503767038689094076378988206631', 'event_type': 'last_trade_price', 'fee_rate_bps': '0', 'market': '0x1c8a4a4de38ae64f120b079474eca7ebfc2cd0e641e30a26bfe1963223fc646e', 'price': '0.15', 'side': 'BUY', 'size': '13.333332', 'timestamp': '1724375540261'}
# {'asks': [{'price': '0.99', 'size': '60020'}, {'price': '0.97', 'size': '50'}, {'price': '0.96', 'size': '2500'}, {'price': '0.8', 'size': '75'}, {'price': '0.79', 'size': '952'}, {'price': '0.69', 'size': '52.98'}, {'price': '0.6', 'size': '200'}, {'price': '0.5', 'size': '200'}, {'price': '0.49', 'size': '1227.8'}, {'price': '0.4', 'size': '200'}, {'price': '0.35', 'size': '434.17'}, {'price': '0.3', 'size': '100'}, {'price': '0.25', 'size': '533.69'}, {'price': '0.23', 'size': '10'}, {'price': '0.21', 'size': '750'}, {'price': '0.18', 'size': '22'}, {'price': '0.17', 'size': '266.3'}, {'price': '0.15', 'size': '9123.74'}], 'asset_id': '40934908860656143479579576067633881276941830984503767038689094076378988206631', 'bids': [{'price': '0.01', 'size': '60147.9'}, {'price': '0.02', 'size': '2422'}, {'price': '0.03', 'size': '1500'}, {'price': '0.04', 'size': '1087.67'}, {'price': '0.05', 'size': '60'}, {'price': '0.09', 'size': '955'}, {'price': '0.1', 'size': '13.88'}, {'price': '0.12', 'size': '1749.2'}, {'price': '0.13', 'size': '2119.25'}], 'event_type': 'book', 'hash': '7462266fbfeaae6ae73f6e9711969d76e0a7c037', 'market': '0x1c8a4a4de38ae64f120b079474eca7ebfc2cd0e641e30a26bfe1963223fc646e', 'timestamp': '1724375540262'}
# {'asks': [{'price': '0.99', 'size': '60147.9'}, {'price': '0.98', 'size': '2422'}, {'price': '0.97', 'size': '1500'}, {'price': '0.96', 'size': '1087.67'}, {'price': '0.95', 'size': '60'}, {'price': '0.91', 'size': '955'}, {'price': '0.9', 'size': '13.88'}, {'price': '0.88', 'size': '1749.2'}, {'price': '0.87', 'size': '2119.25'}], 'asset_id': '112691550711713354714525509796202337193505769808087674259394206524293080902258', 'bids': [{'price': '0.01', 'size': '60020'}, {'price': '0.03', 'size': '50'}, {'price': '0.04', 'size': '2500'}, {'price': '0.2', 'size': '75'}, {'price': '0.21', 'size': '952'}, {'price': '0.31', 'size': '52.98'}, {'price': '0.4', 'size': '200'}, {'price': '0.5', 'size': '200'}, {'price': '0.51', 'size': '1227.8'}, {'price': '0.6', 'size': '200'}, {'price': '0.65', 'size': '434.17'}, {'price': '0.7', 'size': '100'}, {'price': '0.75', 'size': '533.69'}, {'price': '0.77', 'size': '10'}, {'price': '0.79', 'size': '750'}, {'price': '0.82', 'size': '22'}, {'price': '0.83', 'size': '266.3'}, {'price': '0.85', 'size': '9123.74'}], 'event_type': 'book', 'hash': 'cf83ad8e37f570934982ea89f1034e0ed062a576', 'market': '0x1c8a4a4de38ae64f120b079474eca7ebfc2cd0e641e30a26bfe1963223fc646e', 'timestamp': '1724375540262'}
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# <ipython-input-6-a6c351900bbe> in <cell line: 15>()
#      17
#      18     while True:
# ---> 19         m = await websocket.recv()
#      20         if m != "PONG":
#      21           last_time_pong = datetime.datetime.now()
#
# /usr/local/lib/python3.10/dist-packages/websockets/legacy/protocol.py in recv(self)
#     546                 # If asyncio.wait() is canceled, it doesn't cancel
#     547                 # pop_message_waiter and self.transfer_data_task.
# --> 548                 await asyncio.wait(
#     549                     [pop_message_waiter, self.transfer_data_task],
#     550                     return_when=asyncio.FIRST_COMPLETED,
#
# /usr/lib/python3.10/asyncio/tasks.py in wait(fs, timeout, return_when)
#     382     fs = {ensure_future(f, loop=loop) for f in fs}
#     383
# --> 384     return await _wait(fs, timeout, return_when, loop)
#     385
#     386
#
# /usr/lib/python3.10/asyncio/tasks.py in _wait(fs, timeout, return_when, loop)
#     489
#     490     try:
# --> 491         await waiter
#     492     finally:
#     493         if timeout_handle is not None:
#
# CancelledError:
